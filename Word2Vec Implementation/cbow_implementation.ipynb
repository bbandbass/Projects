# %% [markdown]
# <a href="https://colab.research.google.com/github/bbandbass/Projects/blob/main/cbow_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
window_size = 2  # context words로 왼쪽으로 2 단어, 오른쪽으로 2 단어

sentence = """
Regrets, I've had a few.
But then again, too few to mention.
I did what I had to do.
And saw it through without exemption.
I planned each charted course.
Each careful step along the byway.
And more, much more than this, I did it my way.
"""

words = sentence.split()

vocab = set(words)
vocab_size = len(vocab)

word_to_idx = {word:idx for idx, word in enumerate(vocab)}
idx_to_word = {idx:word for idx, word in enumerate(vocab)}

data = []

# context words와 centor word 
for i in range(window_size, len(words) - window_size):
  context = [words[i - window_size : i], words[i + 1 : i + window_size + 1]]
  context = context[0] + context[1]
  center = words[i]
  data.append((context, center))

# %%
data
# Out:
# [(['Regrets,', "I've", 'a', 'few.'], 'had'),
#  (["I've", 'had', 'few.', 'But'], 'a'),
#  (['had', 'a', 'But', 'then'], 'few.'),
#  (['a', 'few.', 'then', 'again,'], 'But'),
#  (['few.', 'But', 'again,', 'too'], 'then'),
#  (['But', 'then', 'too', 'few'], 'again,'),
#  (['then', 'again,', 'few', 'to'], 'too'),
#  (['again,', 'too', 'to', 'mention.'], 'few'),
#  (['too', 'few', 'mention.', 'I'], 'to'),
#  (['few', 'to', 'I', 'did'], 'mention.'),
#  (['to', 'mention.', 'did', 'what'], 'I'),
#  (['mention.', 'I', 'what', 'I'], 'did'),
#  (['I', 'did', 'I', 'had'], 'what'),
#  (['did', 'what', 'had', 'to'], 'I'),
#  (['what', 'I', 'to', 'do.'], 'had'),
#  (['I', 'had', 'do.', 'And'], 'to'),
#  (['had', 'to', 'And', 'saw'], 'do.'),
#  (['to', 'do.', 'saw', 'it'], 'And'),
#  (['do.', 'And', 'it', 'through'], 'saw'),
#  (['And', 'saw', 'through', 'without'], 'it'),
#  (['saw', 'it', 'without', 'exemption.'], 'through'),
#  (['it', 'through', 'exemption.', 'I'], 'without'),
#  (['through', 'without', 'I', 'planned'], 'exemption.'),
#  (['without', 'exemption.', 'planned', 'each'], 'I'),
#  (['exemption.', 'I', 'each', 'charted'], 'planned'),
#  (['I', 'planned', 'charted', 'course.'], 'each'),
#  (['planned', 'each', 'course.', 'Each'], 'charted'),
#  (['each', 'charted', 'Each', 'careful'], 'course.'),
#  (['charted', 'course.', 'careful', 'step'], 'Each'),
#  (['course.', 'Each', 'step', 'along'], 'careful'),
#  (['Each', 'careful', 'along', 'the'], 'step'),
#  (['careful', 'step', 'the', 'byway.'], 'along'),
#  (['step', 'along', 'byway.', 'And'], 'the'),
#  (['along', 'the', 'And', 'more,'], 'byway.'),
#  (['the', 'byway.', 'more,', 'much'], 'And'),
#  (['byway.', 'And', 'much', 'more'], 'more,'),
#  (['And', 'more,', 'more', 'than'], 'much'),
#  (['more,', 'much', 'than', 'this,'], 'more'),
#  (['much', 'more', 'this,', 'I'], 'than'),
#  (['more', 'than', 'I', 'did'], 'this,'),
#  (['than', 'this,', 'did', 'it'], 'I'),
#  (['this,', 'I', 'it', 'my'], 'did'),
#  (['I', 'did', 'my', 'way.'], 'it')]

# %%
def make_context_vector(context, word_to_idx):
    context_index = [word_to_idx[w] for w in context]
    return torch.tensor(context_index, dtype = torch.long)

# %%
def make_center_vector(center, word_to_idx):
  return torch.tensor(word_to_idx[center], dtype = torch.long)

# %% [markdown]
# # CBOW

# %%
class CBOW(nn.Module):
  def __init__(self, vocab_size, projection_size):
    super(CBOW, self).__init__()
    self.projection = nn.Embedding(vocab_size, projection_size)
    self.linear = nn.Linear(projection_size, vocab_size)

  def forward(self, input):
    
    projection = self.projection(input)
    projection_mean = projection.mean(axis = 0)
    output = self.linear(projection_mean)

    return output

# %%
cbow = CBOW(vocab_size, 500)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(cbow.parameters(), lr = 0.01)

# %%
for epoch in range(5000):
  
  loss = 0

  for context, center in data:
    
    context_vector = make_context_vector(context, word_to_idx)
    center_vector = make_center_vector(center, word_to_idx)
    y_hat = cbow(context_vector)
    loss += criterion(y_hat, center_vector)
    
  
  if (epoch + 1) % 10 == 0:
    print('Epoch:', '%04d' % (epoch + 1), 'loss =', '{:.6f}'.format(loss))

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
# Out:
# Epoch: 0010 loss = 10.682316
# Epoch: 0020 loss = 4.289672
# Epoch: 0030 loss = 2.684982
# Epoch: 0040 loss = 1.958663
# Epoch: 0050 loss = 1.544149
# Epoch: 0060 loss = 1.275847
# Epoch: 0070 loss = 1.087830
# Epoch: 0080 loss = 0.948654
# Epoch: 0090 loss = 0.841419
# Epoch: 0100 loss = 0.756222
# Epoch: 0110 loss = 0.686878
# Epoch: 0120 loss = 0.629324
# Epoch: 0130 loss = 0.580774
# Epoch: 0140 loss = 0.539262
# Epoch: 0150 loss = 0.503353
# Epoch: 0160 loss = 0.471982
# Epoch: 0170 loss = 0.444335
# Epoch: 0180 loss = 0.419782
# Epoch: 0190 loss = 0.397831
# Epoch: 0200 loss = 0.378086
# Epoch: 0210 loss = 0.360230
# Epoch: 0220 loss = 0.344002
# Epoch: 0230 loss = 0.329188
# Epoch: 0240 loss = 0.315612
# Epoch: 0250 loss = 0.303123
# Epoch: 0260 loss = 0.291594
# Epoch: 0270 loss = 0.280921
# Epoch: 0280 loss = 0.271008
# Epoch: 0290 loss = 0.261779
# Epoch: 0300 loss = 0.253163
# Epoch: 0310 loss = 0.245102
# Epoch: 0320 loss = 0.237544
# Epoch: 0330 loss = 0.230443
# Epoch: 0340 loss = 0.223758
# Epoch: 0350 loss = 0.217454
# Epoch: 0360 loss = 0.211499
# Epoch: 0370 loss = 0.205864
# Epoch: 0380 loss = 0.200525
# Epoch: 0390 loss = 0.195458
# Epoch: 0400 loss = 0.190644
# Epoch: 0410 loss = 0.186063
# Epoch: 0420 loss = 0.181699
# Epoch: 0430 loss = 0.177537
# Epoch: 0440 loss = 0.173562
# Epoch: 0450 loss = 0.169765
# Epoch: 0460 loss = 0.166131
# Epoch: 0470 loss = 0.162651
# Epoch: 0480 loss = 0.159314
# Epoch: 0490 loss = 0.156114
# Epoch: 0500 loss = 0.153040
# Epoch: 0510 loss = 0.150086
# Epoch: 4540 loss = 0.017396
# Epoch: 4550 loss = 0.017357
# Epoch: 4560 loss = 0.017320
# Epoch: 4570 loss = 0.017283
# Epoch: 4580 loss = 0.017244
# Epoch: 4590 loss = 0.017208
# Epoch: 4600 loss = 0.017171
# Epoch: 4610 loss = 0.017134
# Epoch: 4620 loss = 0.017097
# Epoch: 4630 loss = 0.017061
# Epoch: 4640 loss = 0.017025
# Epoch: 4650 loss = 0.016988
# Epoch: 4660 loss = 0.016952
# Epoch: 4670 loss = 0.016916
# Epoch: 4680 loss = 0.016880
# Epoch: 4690 loss = 0.016844
# Epoch: 4700 loss = 0.016809
# Epoch: 4710 loss = 0.016773
# Epoch: 4720 loss = 0.016739
# Epoch: 4730 loss = 0.016703
# Epoch: 4740 loss = 0.016669
# Epoch: 4750 loss = 0.016634
# Epoch: 4760 loss = 0.016600
# Epoch: 4770 loss = 0.016566
# Epoch: 4780 loss = 0.016532
# Epoch: 4790 loss = 0.016497
# Epoch: 4800 loss = 0.016463
# Epoch: 4810 loss = 0.016429
# Epoch: 4820 loss = 0.016396
# Epoch: 4830 loss = 0.016361
# Epoch: 4840 loss = 0.016327
# Epoch: 4850 loss = 0.016295
# Epoch: 4860 loss = 0.016261
# Epoch: 4870 loss = 0.016229
# Epoch: 4880 loss = 0.016196
# Epoch: 4890 loss = 0.016163
# Epoch: 4900 loss = 0.016130
# Epoch: 4910 loss = 0.016098
# Epoch: 4920 loss = 0.016065
# Epoch: 4930 loss = 0.016034
# Epoch: 4940 loss = 0.016001
# Epoch: 4950 loss = 0.015970
# Epoch: 4960 loss = 0.015938
# Epoch: 4970 loss = 0.015906
# Epoch: 4980 loss = 0.015874
# Epoch: 4990 loss = 0.015843
# Epoch: 5000 loss = 0.015811

# %%
print(context)
print(center)
# Out:
# ['I', 'did', 'my', 'way.']
# it

# %%
for_test = cbow(context_vector)

# %%
print({idx_to_word[torch.argmax(for_test).item()]})
# Out:
# {'it'}

# %% [markdown]
# # Skip-Gram

# %%
class SkipGram(nn.Module):
  def __init__(self, vocab_size, projection_size, window_size):
    super(SkipGram, self).__init__()
    self.projection = nn.Embedding(vocab_size, projection_size)
    self.linear = nn.Linear(projection_size, 2 * window_size * vocab_size)
    self.activation = nn.LogSoftmax(dim = 0)

  def forward(self, input):
    projection = self.projection(input)
    output = self.linear(projection).view(2 * window_size, vocab_size)
    y_hat = self.activation(output)
    
    return y_hat

# %%
skipgram = SkipGram(vocab_size, 500, 2)
criterion = nn.NLLLoss()
optimizer = torch.optim.SGD(skipgram.parameters(), lr = 0.01)

# %%
for epoch in range(5000):
  
  loss = 0

  for context, center in data:
    
    context_vector = make_context_vector(context, word_to_idx)
    center_vector = make_center_vector(center, word_to_idx)
    y_hat = skipgram(center_vector)
    # print("y_hat: ", torch.argmax(y_hat, dim = 1))
    # print("context_vector: ", context_vector)
    loss += criterion(y_hat, context_vector)
    
  if (epoch + 1) % 10 == 0:
    print('Epoch:', '%04d' % (epoch + 1), 'cost =', '{:.6f}'.format(loss))

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
# Out:
# Epoch: 0010 cost = 5.286719
# Epoch: 0020 cost = 3.707929
# Epoch: 0030 cost = 3.230443
# Epoch: 0040 cost = 3.000097
# Epoch: 0050 cost = 2.864495
# Epoch: 0060 cost = 2.775162
# Epoch: 0070 cost = 2.711872
# Epoch: 0080 cost = 2.664686
# Epoch: 0090 cost = 2.628153
# Epoch: 0100 cost = 2.599030
# Epoch: 0110 cost = 2.575270
# Epoch: 0120 cost = 2.555518
# Epoch: 0130 cost = 2.538839
# Epoch: 0140 cost = 2.524566
# Epoch: 0150 cost = 2.512215
# Epoch: 0160 cost = 2.501421
# Epoch: 0170 cost = 2.491908
# Epoch: 0180 cost = 2.483461
# Epoch: 0190 cost = 2.475909
# Epoch: 0200 cost = 2.469119
# Epoch: 0210 cost = 2.462979
# Epoch: 0220 cost = 2.457400
# Epoch: 0230 cost = 2.452310
# Epoch: 0240 cost = 2.447647
# Epoch: 0250 cost = 2.443358
# Epoch: 0260 cost = 2.439402
# Epoch: 0270 cost = 2.435740
# Epoch: 0280 cost = 2.432341
# Epoch: 0290 cost = 2.429178
# Epoch: 0300 cost = 2.426227
# Epoch: 0310 cost = 2.423466
# Epoch: 0320 cost = 2.420880
# Epoch: 0330 cost = 2.418450
# Epoch: 0340 cost = 2.416165
# Epoch: 0350 cost = 2.414009
# Epoch: 0360 cost = 2.411975
# Epoch: 0370 cost = 2.410052
# Epoch: 0380 cost = 2.408230
# Epoch: 0390 cost = 2.406500
# Epoch: 0400 cost = 2.404857
# Epoch: 0410 cost = 2.403298
# Epoch: 0420 cost = 2.401809
# Epoch: 0430 cost = 2.400392
# Epoch: 0440 cost = 2.399039
# Epoch: 0450 cost = 2.397746
# Epoch: 0460 cost = 2.396511
# Epoch: 0470 cost = 2.395327
# Epoch: 0480 cost = 2.394193
# Epoch: 0490 cost = 2.393106
# Epoch: 0500 cost = 2.392061
# Epoch: 0510 cost = 2.391059
# Epoch: 0520 cost = 2.390094
# Epoch: 0530 cost = 2.389167
# Epoch: 0540 cost = 2.388274
# Epoch: 0550 cost = 2.387413
# Epoch: 0560 cost = 2.386584
# Epoch: 0570 cost = 2.385783
# Epoch: 0580 cost = 2.385009
# Epoch: 0590 cost = 2.384262
# Epoch: 0600 cost = 2.383541
# Epoch: 0610 cost = 2.382842
# Epoch: 0620 cost = 2.382167
# Epoch: 0630 cost = 2.381513
# Epoch: 0640 cost = 2.380880
# Epoch: 0650 cost = 2.380266
# Epoch: 0660 cost = 2.379670
# Epoch: 0670 cost = 2.379092
# Epoch: 0680 cost = 2.378532
# Epoch: 0690 cost = 2.377987
# Epoch: 0700 cost = 2.377459
# Epoch: 0710 cost = 2.376946
# Epoch: 0720 cost = 2.376446
# Epoch: 0730 cost = 2.375961
# Epoch: 0740 cost = 2.375488
# Epoch: 0750 cost = 2.375028
# Epoch: 0760 cost = 2.374581
# Epoch: 0770 cost = 2.374144
# Epoch: 0780 cost = 2.373719
# Epoch: 0790 cost = 2.373305
# Epoch: 0800 cost = 2.372901
# Epoch: 0810 cost = 2.372508
# Epoch: 0820 cost = 2.372123
# Epoch: 0830 cost = 2.371748
# Epoch: 0840 cost = 2.371382
# Epoch: 0850 cost = 2.371025
# Epoch: 0860 cost = 2.370676
# Epoch: 0870 cost = 2.370335
# Epoch: 0880 cost = 2.370002
# Epoch: 0890 cost = 2.369675
# Epoch: 0900 cost = 2.369357
# Epoch: 0910 cost = 2.369045
# Epoch: 0920 cost = 2.368742
# Epoch: 0930 cost = 2.368443
# Epoch: 0940 cost = 2.368151
# Epoch: 0950 cost = 2.367866
# Epoch: 0960 cost = 2.367587
# Epoch: 0970 cost = 2.367313
# Epoch: 0980 cost = 2.367044
# Epoch: 0990 cost = 2.366781
# Epoch: 1000 cost = 2.366524
# Epoch: 1010 cost = 2.366272
# Epoch: 1020 cost = 2.366024
# Epoch: 1030 cost = 2.365780
# Epoch: 1040 cost = 2.365543
# Epoch: 1050 cost = 2.365309
# Epoch: 1060 cost = 2.365080
# Epoch: 1070 cost = 2.364855
# Epoch: 1080 cost = 2.364635
# Epoch: 1090 cost = 2.364419
# Epoch: 1100 cost = 2.364206
# Epoch: 1110 cost = 2.363997
# Epoch: 1120 cost = 2.363792
# Epoch: 1130 cost = 2.363591
# Epoch: 1140 cost = 2.363393
# Epoch: 1150 cost = 2.363198
# Epoch: 1160 cost = 2.363007
# Epoch: 1170 cost = 2.362820
# Epoch: 1180 cost = 2.362635
# Epoch: 1190 cost = 2.362454
# Epoch: 1200 cost = 2.362275
# Epoch: 1210 cost = 2.362100
# Epoch: 1220 cost = 2.361927
# Epoch: 1230 cost = 2.361757
# Epoch: 1240 cost = 2.361589
# Epoch: 1250 cost = 2.361425
# Epoch: 1260 cost = 2.361263
# Epoch: 1270 cost = 2.361104
# Epoch: 1280 cost = 2.360948
# Epoch: 1290 cost = 2.360793
# Epoch: 1300 cost = 2.360641
# Epoch: 1310 cost = 2.360491
# Epoch: 1320 cost = 2.360344
# Epoch: 1330 cost = 2.360199
# Epoch: 1340 cost = 2.360056
# Epoch: 1350 cost = 2.359916
# Epoch: 1360 cost = 2.359776
# Epoch: 1370 cost = 2.359640
# Epoch: 1380 cost = 2.359505
# Epoch: 1390 cost = 2.359372
# Epoch: 1400 cost = 2.359242
# Epoch: 1410 cost = 2.359112
# Epoch: 1420 cost = 2.358984
# Epoch: 1430 cost = 2.358860
# Epoch: 1440 cost = 2.358736
# Epoch: 1450 cost = 2.358614
# Epoch: 1460 cost = 2.358493
# Epoch: 1470 cost = 2.358375
# Epoch: 1480 cost = 2.358257
# Epoch: 1490 cost = 2.358142
# Epoch: 1500 cost = 2.358027
# Epoch: 1510 cost = 2.357916
# Epoch: 1520 cost = 2.357804
# Epoch: 1530 cost = 2.357695
# Epoch: 1540 cost = 2.357587
# Epoch: 1550 cost = 2.357480
# Epoch: 1560 cost = 2.357374
# Epoch: 1570 cost = 2.357270
# Epoch: 1580 cost = 2.357168
# Epoch: 1590 cost = 2.357066
# Epoch: 4810 cost = 2.346350
# Epoch: 4820 cost = 2.346338
# Epoch: 4830 cost = 2.346328
# Epoch: 4840 cost = 2.346316
# Epoch: 4850 cost = 2.346306
# Epoch: 4860 cost = 2.346295
# Epoch: 4870 cost = 2.346284
# Epoch: 4880 cost = 2.346273
# Epoch: 4890 cost = 2.346263
# Epoch: 4900 cost = 2.346253
# Epoch: 4910 cost = 2.346242
# Epoch: 4920 cost = 2.346231
# Epoch: 4930 cost = 2.346220
# Epoch: 4940 cost = 2.346210
# Epoch: 4950 cost = 2.346200
# Epoch: 4960 cost = 2.346189
# Epoch: 4970 cost = 2.346179
# Epoch: 4980 cost = 2.346168
# Epoch: 4990 cost = 2.346158
# Epoch: 5000 cost = 2.346148

# %%
print(context)
print(center)
# Out:
# ['I', 'did', 'my', 'way.']
# it

# %%
test = skipgram(center_vector)

# %%
print([idx_to_word[torch.argmax(i).item()] for i in test])
# Out:
# ['I', 'saw', 'my', 'way.']

# %%
class SkipGram2(nn.Module):
  def __init__(self, vocab_size, projection_size, window_size):
    super(SkipGram2, self).__init__()
    self.projection = nn.Embedding(vocab_size, projection_size)
    self.linear = nn.ModuleList()
    for i in range(2 * window_size):
      self.linear.append(nn.Linear(projection_size, vocab_size))
    self.activation = nn.LogSoftmax(dim = 0)

  def forward(self, input):
    
    y_hat = []
    projection = self.projection(input)
    for i in range(len(self.linear)):
      output = self.linear[i](projection)
      y_hat.append(self.activation(output))
    
    return y_hat

# %%
skipgram2 = SkipGram2(vocab_size, 500, 2)

criterion = nn.NLLLoss()
optimizer = torch.optim.SGD(skipgram2.parameters(), lr = 0.01)

# %%
skipgram2
# Out:
# SkipGram2(
#   (projection): Embedding(39, 500)
#   (linear): ModuleList(
#     (0): Linear(in_features=500, out_features=39, bias=True)
#     (1): Linear(in_features=500, out_features=39, bias=True)
#     (2): Linear(in_features=500, out_features=39, bias=True)
#     (3): Linear(in_features=500, out_features=39, bias=True)
#   )
#   (activation): LogSoftmax(dim=0)
# )

# %%
center_vector
# Out:
# tensor(30)

# %%
for epoch in range(5000):
  
  loss = 0

  for context, center in data:
    
    target_vectors = make_context_vector(context, word_to_idx)
    # print(target_vectors)
    # print(target_vectors.dim())
    center_vector = make_center_vector(center, word_to_idx)
    # print(center_vector.dim())
    y_hat = skipgram2(center_vector)
    for i in range(len(target_vectors)):
      loss += criterion(y_hat[i], target_vectors[i])
    
  if (epoch + 1) % 10 == 0:
    print('Epoch:', '%04d' % (epoch + 1), 'cost =', '{:.6f}'.format(loss))

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
# Out:
# Epoch: 0010 cost = 172.291519
# Epoch: 0020 cost = 181.407959
# Epoch: 0030 cost = 169.161606
# Epoch: 0040 cost = 168.770111
# Epoch: 0050 cost = 163.374573
# Epoch: 0060 cost = 169.604935
# Epoch: 0070 cost = 155.532181
# Epoch: 0080 cost = 162.100311
# Epoch: 0090 cost = 154.394669
# Epoch: 0100 cost = 153.096313
# Epoch: 0110 cost = 147.935806
# Epoch: 0120 cost = 130.192886
# Epoch: 0130 cost = 141.927216
# Epoch: 4950 cost = 47.264122
# Epoch: 4960 cost = 47.263371
# Epoch: 4970 cost = 47.262615
# Epoch: 4980 cost = 47.261871
# Epoch: 4990 cost = 47.261135
# Epoch: 5000 cost = 47.260357

# %%
print(context)
print(center)
# Out:
# ['I', 'did', 'my', 'way.']
# it

# %%
for_test = skipgram2(center_vector)

# %%
print([idx_to_word[torch.argmax(i).item()] for i in for_test])
# Out:
# ['I', 'did', 'through', 'way.']

# %% [markdown]
# # Gensim

# %%
pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 50.6 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.8/dist-packages (from konlpy) (1.21.6)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 36.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from JPype1>=0.7.0->konlpy) (23.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (4.64.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Okt
from tqdm import tqdm

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/kocohub/korean-hate-speech/master/unlabeled/unlabeled_comments_1.txt", filename="comments.txt")
# Out:
# ('comments.txt', <http.client.HTTPMessage at 0x7f011068da00>)

# %%
train_data = pd.read_table('comments.txt', on_bad_lines='skip', header = None)
train_data.columns = ['댓글']

# %%
train_data.head()
# Out:
#                                                   댓글
# 0  지드래곤은 난봉꾼이란...댓글도 달렸네 ㅋㅋ 이주연 학창시절 사진 보고 와라. 요즘...
# 1                             이주연은 알겠는데 지디는 뭐하는 듣보잡여
# 2  부럽네요. 나도 불과 한달전까진 허니문베이비를 꿈꿨는데 이제 다 부질없네요. 당연히...
# 3  이주연을 모르는 애들이 많네. 해체된 애프터스쿨 멤버로 당시는 주연이 예명. 인기나...
# 4                                              겨론했으면

# %%
print(len(train_data))
# Out:
# 499995

# %%
print("결측치 존재:",train_data.isnull().values.any())
train_data = train_data.dropna()
print("결측치 존재:", train_data.isnull().values.any())
print(len(train_data))
# Out:
# 결측치 존재: True
# 결측치 존재: False
# 499915

# %%
# 정규 표현식을 통한 한글 외 문자 제거
train_data['댓글'] = train_data['댓글'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data.head()
# Out:
# <ipython-input-32-438c6ebdaa4e>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['댓글'] = train_data['댓글'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
#                                                   댓글
# 0  지드래곤은 난봉꾼이란댓글도 달렸네 ㅋㅋ 이주연 학창시절 사진 보고 와라 요즘 웬만한...
# 1                             이주연은 알겠는데 지디는 뭐하는 듣보잡여
# 2  부럽네요 나도 불과 한달전까진 허니문베이비를 꿈꿨는데 이제 다 부질없네요 당연히 순...
# 3  이주연을 모르는 애들이 많네 해체된 애프터스쿨 멤버로 당시는 주연이 예명 인기나 포...
# 4                                              겨론했으면

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

okt = Okt()

tokenized_data = []
for sentence in tqdm(train_data['댓글']):
    # 토큰화
    tokenized_sentence = okt.morphs(sentence, stem=True) 
    # 불용어 제거
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] 
    tokenized_data.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 499915/499915 [52:40<00:00, 158.17it/s]

# %%
tokenized_data
# Out:
# [['지드래곤',
#   '난봉',
#   '꾼',
#   '이란',
#   '댓글',
#   '달리다',
#   'ㅋㅋ',
#   '이주연',
#   '학창시절',
#   '사진',
#   '보고',
#   '오다',
#   '요즘',
#   '웬만하다',
#   '여자',
#   '연예인',
#   '하고',
#   '붙이다',
#   '놓다',
#   '미모',
#   '최고',
#   '이다',
#   'ㅋ',
#   '대다',
#   '얼짱',
#   '출신'],
#  ['이주연', '알다', '지', '디', '뭐', '듣보잡', '여'],
#  ['부럽다',
#   '나다',
#   '불과',
#   '달전',
#   '까진',
#   '허니문',
#   '베이비',
#   '꿈꾸다',
#   '이제',
#   '다',
#   '부질없다',
#   '당연하다',
#   '순결하다',
#   '믿다',
#   '그래서',
#   '첫날',
#   '밤',
#   '까지',
#   '기다리다',
#   '주다',
#   '배신',
#   '감',
#   '만',
#   '듭니',
#   '다',
#   '첫날',
#   '밤',
#   '와이프',
#   '피',
#   '안',
#   '흘리다',
#   '처가',
#   '집',
#   '식구',
#   '일부러',
#   '절',
#   '속이다',
#   '생각',
#   '화도',
#   '나다',
#   '어제',
#   '처가',
#   '지다',
#   '안',
#   '가다',
#   '혼자',
#   '울',
#   '고',
#   '가다',
#   '오다',
#   '지금',
#   '까지',
#   '한마디',
#   '안해',
#   '요',
#   '이혼',
#   '하고',
#   '싶다'],
#  ['이주연',
#   '을',
#   '모르다',
#   '애',
#   '많다',
#   '해체',
#   '되다',
#   '애프터스쿨',
#   '멤버',
#   '로',
#   '당시',
#   '주연',
#   '예명',
#   '인기',
#   '나',
#   '포텐',
#   '안',
#   '터지다',
#   '순',
#   '수',
#   '미모',
#   '만으로는',
#   '애프터스쿨',
#   '에서',
#   '원',
#   '탑',
#   '이다',
#   '진짜',
#   '자연미인',
#   '이다'],
#  ['겨론'],
#  ['이주연', '아깝다', '진심'],
#  ['방탄',
#   '건드리다',
#   '인간',
#   '적',
#   '해외',
#   '활동',
#   '지',
#   '금주',
#   '터',
#   '시작',
#   '인데',
#   '터지다',
#   '진짜',
#   '전',
#   '세계',
#   '적',
#   '활짝',
#   '피기',
#   '전',
#   '난리',
#   '나다',
#   '국위',
#   '선양',
#   '하',
#   '떠오르다',
#   '샛별',
#   '제발',
#   '건드리다',
#   '타다',
#   '들다',
#   '만약',
#   '연애',
#   '들키다',
#   '않다',
#   'ㅠㅠ'],
#  ['선남선녀', '만나다'],
#  ['문', '재앙', '또뭘', '덥다', '싶다', 'ㄷㄷㄷ'],
#  ['주연', '아깝다', '해', '요'],
#  ['지',
#   '디',
#   '아이유',
#   '랑',
#   '너무',
#   '자다',
#   '어울리다',
#   '아쉽다',
#   '마지막',
#   '아이유',
#   '랑',
#   '해',
#   '줄다',
#   '인류',
#   '축복',
#   '을',
#   '위해',
#   '서'],
#  ['오빠', '괴롭다', '마', '요'],
#  ['너희', '실수', '사람', '못', '고르다', '거', '오', '보', '야'],
#  ['모두',
#   '거짓',
#   '기',
#   '사임',
#   '같이',
#   '찍다',
#   '사진',
#   '없다',
#   '지',
#   '디',
#   '아니다',
#   '분명하다',
#   '못',
#   '을',
#   '박다',
#   '집',
#   '근처',
#   '사진',
#   '나다',
#   '구하라',
#   '설리',
#   '연합',
#   '사',
#   '진보',
#   '니',
#   '친구',
#   '인거',
#   '같다',
#   '여기',
#   '서',
#   '왜',
#   '나오다',
#   '이제',
#   '안되다',
#   '치밀하다',
#   '계획',
#   '몰다',
#   '알바',
#   '쓰다',
#   '제대로',
#   '건',
#   '크게',
#   '관종짓',
#   '을',
#   'ㅉㅉ',
#   '알바',
#   '이나',
#   '믿다',
#   '대중',
#   '안',
#   '믿다',
#   '스치다',
#   '간',
#   '인연',
#   '스토커',
#   '짓',
#   '이제',
#   '접다',
#   '제발'],
#  ['문', '재앙', '발악', '하고', '있다'],
#  ['매력', '적', '이네', '친구', '차다', '여자', '여자', '네'],
#  ['이주연', '진짜', '예쁘다', '함', 'ㅇㅇ'],
#  ['솔직하다',
#   '사귀다',
#   '말다',
#   '상관없다',
#   '사실',
#   '만',
#   '말',
#   '저',
#   '날',
#   '승리',
#   '펜션',
#   '놀다',
#   '간걸',
#   '로',
#   '알다',
#   '단',
#   '둘이서',
#   '놓다',
#   '눈치',
#   '없이',
#   '펜션',
#   '놀다',
#   '가다',
#   '게다가',
#   '지',
#   '디보',
#   '다',
#   '매다',
#   '찍히다',
#   '사진',
#   '더',
#   '많다',
#   '보다',
#   '매다',
#   '사귀다',
#   '아니다'],
#  ['주연',
#   '구혜선',
#   '박한별',
#   '얼짱',
#   '이다',
#   '무슨',
#   '급',
#   '안',
#   '맞다',
#   '지',
#   '롤',
#   '뜨다',
#   '악플달다',
#   '니',
#   '지드래곤',
#   '빠순이',
#   '거울',
#   '안보',
#   '냐',
#   '니',
#   '더',
#   '이쁘다',
#   '양심',
#   '껏',
#   '대답',
#   '해보다',
#   'ㅋㅋㅋ'],
#  ['모두',
#   '거짓',
#   '기',
#   '사임',
#   '같이',
#   '찍다',
#   '사진',
#   '없다',
#   '지',
#   '디',
#   '아니다',
#   '분명하다',
#   '못',
#   '을',
#   '박다',
#   '집',
#   '근처',
#   '사진',
#   '나다',
#   '구하라',
#   '설리',
#   '연합',
#   '사',
#   '진보',
#   '니',
#   '친구',
#   '인거',
#   '같다',
#   '여기',
#   '서',
#   '왜',
#   '나오다',
#   '이제',
#   '안되다',
#   '치밀하다',
#   '계획',
#   '몰다',
#   '알바',
#   '쓰다',
#   '제대로',
#   '건',
#   '크게',
#   '관종짓',
#   '을',
#   'ㅉㅉ',
#   '알바',
#   '이나',
#   '믿다',
#   '대중',
#   '안',
#   '믿다',
#   '완전',
#   '스토커',
#   '여자',
#   '라도',
#   '소름끼치다'],
#  ['모두',
#   '거짓',
#   '기',
#   '사임',
#   '같이',
#   '찍다',
#   '사진',
#   '없다',
#   '지',
#   '디',
#   '아니다',
#   '분명하다',
#   '못',
#   '을',
#   '박다',
#   '집',
#   '근처',
#   '사진',
#   '나다',
#   '이제',
#   '안되다',
#   '치밀하다',
#   '계획',
#   '몰다',
#   '알바',
#   '쓰다',
#   '제대로',
#   '건',
#   '크게',
#   '관종짓',
#   '을',
#   'ㅉㅉ',
#   '알바',
#   '이나',
#   '믿다',
#   '대중',
#   '안',
#   '믿다',
#   '스치다',
#   '간',
#   '인연',
#   '이니',
#   '이제',
#   '스토커',
#   '그만하다',
#   '제발',
#   '지',
#   '디',
#   '이주연',
#   '고소하다',
#   '허위',
#   '날조',
#   '기사'],
#  ['모두',
#   '거짓',
#   '기',
#   '사임',
#   '같이',
#   '찍다',
#   '사진',
#   '없다',
#   '지',
#   '디',
#   '아니다',
#   '분명하다',
#   '못',
#   '을',
#   '박다',
#   '집',
#   '근처',
#   '사진',
#   '나다',
#   '이제',
#   '안되다',
#   '치밀하다',
#   '계획',
#   '몰다',
#   '알바',
#   '쓰다',
#   '제대로',
#   '건',
#   '크게',
#   '관종짓',
#   '을',
#   'ㅉㅉ',
#   '알바',
#   '이나',
#   '믿다',
#   '대중',
#   '안',
#   '믿다',
#   '스치다',
#   '간',
#   '인연',
#   '이니',
#   '이제',
#   '스토커',
#   '그만하다',
#   '제발',
#   '지',
#   '디',
#   '이주연',
#   '고소하다',
#   '허위',
#   '날조',
#   '기사'],
#  ['지', '디', '아이유', '건드리다', '않다', '아이유', '안', '넘어오다'],
#  ['이주연',
#   '보크',
#   '타이어',
#   '만도',
#   '못',
#   '녀',
#   '급',
#   '어떻다',
#   '사',
#   '람보',
#   '눈',
#   '없다',
#   '마네',
#   '하',
#   '는걸',
#   '보다',
#   '기',
#   '차다',
#   '기',
#   '가차',
#   'ㅋㅋㅋ',
#   '콩깍지',
#   '벗다',
#   '주제',
#   '파악',
#   '하자'],
#  ['뭘', '실망', '이야', '아', '지드래곤', '안', '사귀다', '줄', '알다', '빠순이', '아', 'ㅋㅋㅋㅋ'],
#  ['여자',
#   '주연',
#   '너무',
#   '깔다',
#   'ㅋㅋㅋ',
#   '아무리',
#   '지다',
#   '빠르다',
#   '같다',
#   '여자',
#   '끼리',
#   '감싸다',
#   'ㅎㅎ'],
#  ['둘',
#   '좋다',
#   '사귀다',
#   '급',
#   '매기',
#   '사람',
#   '웰케',
#   '많다',
#   '그렇다고',
#   '저',
#   '정도',
#   '외모',
#   '돈',
#   '이상',
#   '가지다',
#   '것',
#   '아니다'],
#  ['새해',
#   '부터',
#   '이주연',
#   '깎다',
#   '내리다',
#   '수고',
#   '다',
#   '이주연',
#   '발톱',
#   '때',
#   '보다',
#   '못',
#   '생기다',
#   '오크',
#   '쿵쾅',
#   '녀',
#   '아',
#   'ㅋㅋㅋ'],
#  ['이주연', '님', '성격', '진짜', '좋다', '보이다', '예쁘다', '연애', '바', '래', '요'],
#  ['이준',
#   '정소',
#   '미기',
#   '살다',
#   '사실',
#   '지다',
#   '이주연',
#   '기사',
#   '거짓',
#   '사진',
#   '글',
#   '너무',
#   '비교',
#   '되다',
#   '이주연',
#   '관종짓',
#   '을',
#   '이번',
#   '엔',
#   '크게',
#   '있다',
#   '음모',
#   '두',
#   '믿다',
#   '말다',
#   '거짓말',
#   '임',
#   '젠',
#   '발목',
#   '잡기',
#   '틀리다',
#   '복수',
#   '것',
#   '이다',
#   '팩트',
#   '이다',
#   '가지가지',
#   '구하라',
#   '설리',
#   '연합',
#   '글',
#   '이름',
#   '저번',
#   '같이',
#   '사진',
#   '찍다',
#   '친구',
#   '인가',
#   '보다'],
#  ['문재인',
#   '정부',
#   '뭘',
#   '덮다',
#   '이주연',
#   '정소민',
#   '까지',
#   '빵빵',
#   '터',
#   '트리',
#   '네',
#   '요',
#   '하지만',
#   '깨',
#   '시민',
#   '이렇다',
#   '저',
#   '질',
#   '스러운',
#   '연예인',
#   '돌려막기',
#   '현혹',
#   '되다',
#   '않다',
#   '무한'],
#  ['새해', '첫날', '부터', '문재인', '정부', '뭘', '덮다', '이렇다', '기사', '터뜨리다'],
#  ['산불',
#   '재앙',
#   '또',
#   '감추다',
#   '열애설',
#   '터뜨리다',
#   '하여간',
#   '정부',
#   '어휴',
#   '답',
#   '없다',
#   '답',
#   '없다'],
#  ['이주연',
#   '님',
#   '되게',
#   '이쁘다',
#   '오빠',
#   '오래',
#   '가요',
#   '어울리다',
#   '주연',
#   '님',
#   '울',
#   '오빠',
#   '부다',
#   '탁하다'],
#  ['이주연', '이쁘다', '왜', '결혼', '까지', '해', '라', '태양', '처럼'],
#  ['지다', '실망', '이네', '개념', '스시', '녀', '만', '사귀다', '알다', '김치', '녀', '사귀다'],
#  ['어',
#   '울',
#   '령',
#   '주연',
#   '씨',
#   '길다',
#   '세련되다',
#   '느낌',
#   '이라',
#   '세다',
#   '크다',
#   '지',
#   '디',
#   '면',
#   '대박',
#   '이다'],
#  ['우리', '지', '용이', '그', '누구', '랑', '사귀다', '지랄', '들이다', 'ㅠㅠ'],
#  ['지드래곤', '이쁘다', '여자', '잡다', '땡잡다', '보다'],
#  ['지다',
#   '마약',
#   '사건',
#   '사람',
#   '욕',
#   '마약',
#   '솔직하다',
#   '왜',
#   '나쁘다',
#   '물다',
#   '다',
#   '들다',
#   '아무',
#   '대답',
#   '못',
#   '내',
#   '미국인',
#   '친구',
#   '코카인',
#   '흡입',
#   '나쁘다',
#   '그게',
#   '왜',
#   '나쁘다',
#   '물다',
#   '그냥',
#   '나쁘다',
#   '사람',
#   '정신',
#   '을',
#   '몽롱',
#   '만들다',
#   '이렇게',
#   '말함',
#   '결국',
#   '명쾌하다',
#   '답변',
#   '을',
#   '아무',
#   '못',
#   '지',
#   '디',
#   '야',
#   '힘내다',
#   '여기',
#   '북한',
#   '이냐',
#   '대마초',
#   '하',
#   '건',
#   '말다',
#   '뭔',
#   '상관',
#   '이냐'],
#  ['정부', '뭘', '또', '숨다', '새해', '부터', '열애설', '터', '트릴', '끄다'],
#  ['헐다', '디패', '대박', 'ㄷㄷㄷ'],
#  ['진짜', '연인', '관계', '맞다', '예쁘다', '사랑', '응원'],
#  ['지다', '부럽다', '모든', '대다', '여자', '다', '만날', '능력', '돼다', 'ㅋㅋㅋ'],
#  ['성공하다', '아랫', '도리', '마구', '굴려', '야', '지다', 'ㅋㅋ'],
#  ['그', '지', '근', '성인', '여자', '안', '만나다', '다행'],
#  ['관심', '없다', '지', '디', '블랙', '카드', '아깝다', '뿐', '이다', 'ㅋ'],
#  ['우리', '뷔', '오빠', '더', '낳다'],
#  ['어리다',
#   '이쁘다',
#   '가슴',
#   '크다',
#   '여자',
#   '널렸',
#   '고',
#   '지다',
#   '정도',
#   '면',
#   '아무나',
#   '골',
#   '라서',
#   '사귀다',
#   '수',
#   '있다',
#   '왜',
#   '연상',
#   '심지어',
#   '자기',
#   '보다',
#   '키도',
#   '크다',
#   '여자',
#   '만나다',
#   '건지다'],
#  ['모두',
#   '거짓',
#   '기',
#   '사임',
#   '같이',
#   '찍다',
#   '사진',
#   '없다',
#   '지',
#   '디',
#   '아니다',
#   '분명하다',
#   '못',
#   '을',
#   '박다',
#   '집',
#   '근처',
#   '사진',
#   '나다',
#   '구하라',
#   '설리',
#   '연합',
#   '사',
#   '진보',
#   '니',
#   '친구',
#   '인거',
#   '같다',
#   '여기',
#   '서',
#   '왜',
#   '나오다',
#   '이제',
#   '안되다',
#   '치밀하다',
#   '계획',
#   '몰다',
#   '알바',
#   '쓰다',
#   '제대로',
#   '건',
#   '크게',
#   '관종짓',
#   '을',
#   'ㅉㅉ',
#   '알바',
#   '이나',
#   '믿다',
#   '대중',
#   '안',
#   '믿다',
#   '스치다',
#   '간',
#   '인연',
#   '이니',
#   '이제',
#   '스토커',
#   '그만하다',
#   '제발'],
#  ['새해',
#   '부터',
#   '개',
#   '같다',
#   '소리',
#   '기자',
#   '쉐',
#   '이야',
#   '개',
#   '소리',
#   '왈왈',
#   '간',
#   '주둥이',
#   '짖다',
#   '찌다',
#   '버리다'],
#  ['문', '재앙', '대체', '뭐', '덮다'],
#  ['이다', '또', '뭘', '숨다', '새해', '부터', '쏟아내다', '게', '나라', '냐'],
#  ['디스패치',
#   '고소',
#   '당하다',
#   '좋다',
#   '시작',
#   '연',
#   '인들',
#   '깽판',
#   '치고',
#   '저작권',
#   '있다',
#   '사람',
#   '사진',
#   '동의',
#   '없이',
#   '개재',
#   '하고',
#   '광고',
#   '수익',
#   '가져가다',
#   '갑질',
#   '까지',
#   '개',
#   '쓰다',
#   '렉',
#   '들다'],
#  ['오다',
#   '지',
#   '디씨',
#   '주연',
#   '씨',
#   '선남선녀',
#   '커플',
#   '이네',
#   '요',
#   '무술년',
#   '새해',
#   '호',
#   '연예인',
#   '커플',
#   '이쁘다',
#   '사랑',
#   '오래오래',
#   '가세',
#   '요'],
#  ['너무',
#   '부럽다',
#   '네',
#   '여',
#   '지용',
#   '오빠',
#   '돈',
#   '두',
#   '엄청',
#   '많다',
#   'ㅠ',
#   '휴',
#   '남친',
#   '그렇지만',
#   '남자',
#   '이상하다',
#   '지다',
#   '들차다',
#   '쓰다',
#   '아무렇다',
#   '않다',
#   '쓰다',
#   '왜',
#   '백',
#   '사주',
#   '아깝다',
#   '남자',
#   '에게',
#   '차갑다',
#   '자존심',
#   '듯이',
#   '여자',
#   '에게는',
#   '백이',
#   '자존심',
#   '이라',
#   '고요'],
#  ['사실',
#   '가다',
#   '남자',
#   '로서',
#   '매력',
#   '적',
#   '이진',
#   '않다',
#   '루저',
#   '잖다',
#   '키',
#   '인',
#   '주',
#   '연일',
#   '사귀다',
#   '영광',
#   '알다'],
#  ['지', '디', '아이유', '랑', '어울리다', '내', '다', '아쉽다'],
#  ['지',
#   '디',
#   '키',
#   '작다',
#   '너',
#   '네',
#   '달리',
#   '얼굴',
#   '작고',
#   '비율',
#   '좋다',
#   '개쩌',
#   '데',
#   '너',
#   '네',
#   '얼굴',
#   'ㅈ',
#   '같다',
#   '대가리',
#   '돌',
#   '같이',
#   '커서',
#   '무시',
#   '당하다',
#   'ㄷ'],
#  ['이준',
#   '정소민',
#   '처럼',
#   '같이',
#   '찍다',
#   '사진',
#   '을',
#   '내보내다',
#   '믿다',
#   '집',
#   '근처',
#   '가다',
#   '찍다',
#   '사진',
#   '나다',
#   '그렇게',
#   '구하라',
#   '설리',
#   '열애설',
#   '나오다',
#   '보다',
#   '이주연',
#   '동참',
#   '마지막',
#   '복수',
#   '하',
#   '나',
#   '보다',
#   '셋',
#   '서얼',
#   '마전',
#   '셋',
#   '같이',
#   '찍다',
#   '사진',
#   '있다',
#   '여러분',
#   '모두',
#   '거짓',
#   '이니',
#   '믿다',
#   '셈',
#   '예전',
#   '잠깐',
#   '스치다',
#   '간',
#   '인연',
#   '인데',
#   '발목',
#   '잡다',
#   '거짓',
#   '기사',
#   '쓰다',
#   '있다',
#   '임',
#   '가지가지',
#   '이주연',
#   'ㅉㅉㅉ',
#   '대중',
#   '다',
#   '모르다',
#   '같다'],
#  ['시집', '장가', '갈다', '나이', '돼다', '둘', '좋다', '결혼'],
#  ['대마', '쟁이', '빠순이', '부들부들', '이주연', '나쁘다', '년', '이야', '빼액'],
#  ['종현',
#   '너',
#   '네',
#   '악플',
#   '때문',
#   '고생',
#   '또',
#   '네',
#   '너',
#   '네',
#   '왜',
#   '발전',
#   '없다',
#   '가정교육',
#   '을',
#   '못',
#   '받다'],
#  ['괜찮다', '열심히', '사랑', '이번', '년도', '좋다', '노래', '기대하다'],
#  ['키코', '아니다', '다행', '인데', '차라리', '이주연', '낫다'],
#  ['저',
#   '거',
#   '다',
#   '구',
#   '라임',
#   '저번',
#   '처럼',
#   '사진',
#   '짜지다',
#   '관종짓',
#   '믿다',
#   '말다',
#   '다',
#   '들다'],
#  ['노콘',
#   '최고다',
#   '정말',
#   '사랑',
#   '콘돔',
#   '을',
#   '쓴다',
#   '구라',
#   '다',
#   '옥황상제',
#   '랑',
#   '하이파이브',
#   '기분',
#   '이다'],
#  ['여기', '서', '빅뱅', '깔다', '것', '메이비', '방탄', '빠', '인가'],
#  ['결혼', '짝', '결혼', '짝'],
#  ['오다', '정부', '에서', '뭘', '덮다', '이르다'],
#  ['친딸',
#   '고준희',
#   '때리다',
#   '죽이다',
#   '낄낄대다',
#   '프라모델',
#   '인스타',
#   '올리다',
#   '가족',
#   '여행',
#   '다니다',
#   '이웃',
#   '딸',
#   '생일',
#   '먹여주다',
#   '남다',
#   '거',
#   '라며',
#   '미역국',
#   '돌리다',
#   '경찰서',
#   '가다',
#   '나',
#   '딸',
#   '없다',
#   '못',
#   '사다',
#   '내',
#   '딸',
#   '찾다',
#   '달라',
#   '울부짖다',
#   '친부',
#   '고병식',
#   '전라디언',
#   '오유',
#   '루리웹',
#   '회원',
#   '폭동',
#   '을',
#   '민주화',
#   '운동',
#   '이라고',
#   '날조',
#   '미화',
#   '홍보',
#   '민주',
#   '노총',
#   '금속노조',
#   '원',
#   '좋아하다',
#   '음식',
#   '홍어',
#   '일본술',
#   '정치성향',
#   '문재인',
#   '김대중',
#   '노무현',
#   '지지',
#   '하고',
#   '박근혜',
#   '이명박',
#   '증오',
#   '그렇다',
#   '보다',
#   '이준',
#   '부모',
#   '전라도',
#   '이고',
#   '박근혜',
#   '탄핵',
#   '구속',
#   '하고',
#   '문재인',
#   '집권',
#   '시키다',
#   '자다',
#   '촛불시위',
#   '이준',
#   '고병식',
#   '유사',
#   '점',
#   '많다'],
#  ['솔직하다', '수지', '보다', '이쁘다', 'ㅇㅈ'],
#  ['이주연',
#   '서민',
#   '티',
#   '졸라',
#   '나',
#   'ㅋㅋ',
#   '지',
#   '디',
#   '갤러리아',
#   '포레',
#   '살다',
#   '구리구리',
#   '구리시',
#   '사다',
#   'ㅋㅋ'],
#  ['모두',
#   '거짓',
#   '기',
#   '사임',
#   '같이',
#   '찍다',
#   '사진',
#   '없다',
#   '지',
#   '디',
#   '아니다',
#   '분명하다',
#   '못',
#   '을',
#   '박다',
#   '집',
#   '근처',
#   '사진',
#   '나다',
#   '구하라',
#   '설리',
#   '연합',
#   '사',
#   '진보',
#   '니',
#   '친구',
#   '인거',
#   '같다',
#   '여기',
#   '서',
#   '왜',
#   '나오다',
#   '이제',
#   '안되다',
#   '치밀하다',
#   '계획',
#   '몰다',
#   '알바',
#   '쓰다',
#   '제대로',
#   '건',
#   '크게',
#   '관종짓',
#   '을',
#   'ㅉㅉ',
#   '알바',
#   '이나',
#   '믿다',
#   '대중',
#   '안',
#   '믿다'],
#  ['작고', '지다', '궁합', '맞다', '보넹', '이주연', '좁다'],
#  ['기레기',
#   '기자',
#   '야',
#   '거짓',
#   '조작',
#   '시사',
#   '내면',
#   '콩밥',
#   '먹다',
#   '알',
#   '지',
#   '이주연',
#   '관종',
#   '기레기',
#   '아',
#   '휴',
#   '어떻다',
#   '이렇다',
#   '여우',
#   '한테',
#   '걸리다',
#   '스토커',
#   '처럼',
#   '무섭다',
#   '같다',
#   '거짓',
#   '기사',
#   '니',
#   '믿다',
#   '말다'],
#  ['모욕',
#   '성희롱',
#   '분',
#   '캡쳐',
#   '소속사',
#   '로',
#   '바로',
#   '보내다',
#   '중임',
#   '발견',
#   '즉시',
#   '계속',
#   '보내다',
#   '중임',
#   'ㅎ',
#   '명중',
#   '명',
#   '경찰',
#   '소환',
#   '되다'],
#  ['세상', '에서', '제일', '예쁘다', '이주연'],
#  ['지', '디', '아니다', '지다', '매다', '사귀다'],
#  ['정치',
#   '과학',
#   '사회',
#   '관련',
#   '기사',
#   '댓글',
#   '관심',
#   '남자',
#   '여자',
#   '연예',
#   '관련',
#   '기사',
#   '댓글',
#   '관심',
#   '여자',
#   'ㅋㅋㅋㅋㅋㅋㅋ',
#   '실화',
#   '냐',
#   '이러니까',
#   '여자',
#   '평균',
#   '임금',
#   '요',
#   '직',
#   '비율',
#   '낮다',
#   'ㅋㅋㅋ',
#   '근데',
#   '차별',
#   '핑계',
#   '오지',
#   '게',
#   '대다',
#   'ㅋㅋ'],
#  ['약물', '검사', '두', '배', '드나', '핵심'],
#  ['딱',
#   '보다',
#   '엔조이',
#   '구만',
#   'ㅋ',
#   '남자',
#   '색휘',
#   '자다',
#   '알다',
#   '고대로',
#   '딱',
#   '그만큼',
#   '행동',
#   'ㅎㅎ'],
#  ['지',
#   '디',
#   '이주연',
#   '조심',
#   '또',
#   '조심하다',
#   '수',
#   '밖에',
#   '없다',
#   '는걸',
#   '알다',
#   'ㅋㅋㅋㅋㅋ',
#   '이렇게',
#   '스토킹',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '악질',
#   '디패',
#   'ㅋㅋㅋ',
#   '악질',
#   '스토킹',
#   '마지막',
#   '그',
#   '더',
#   '이상',
#   '외롭다',
#   '않다',
#   '바란',
#   '댘',
#   'ㅋㅋㅋㅋㅋ',
#   '존웃',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '그러면',
#   '연예',
#   '인들',
#   '뒷',
#   '꽁',
#   '무늬',
#   '고만',
#   '따라다니다',
#   '아이돌',
#   '왜',
#   '숨다',
#   '연애',
#   '되다',
#   '니',
#   '파파라치',
#   '때문',
#   '잖다',
#   '쟤',
#   '네',
#   '숨좀',
#   '쉬',
#   '게',
#   '해주다',
#   '없다',
#   '정신병',
#   '당연하다',
#   '생기다'],
#  ['빅뱅', '군대', '가다', '더', '슬프다'],
#  ['완전멕',
#   '이네',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '팬',
#   '알다',
#   '척',
#   '덤덤하다',
#   '척',
#   '지리다',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '지',
#   '디',
#   '왜',
#   '매니저',
#   '귀찮다',
#   '만들다',
#   'ㅉㅉ',
#   '한심하다',
#   '놈'],
#  ['이준',
#   '정소',
#   '미기',
#   '살다',
#   '사실',
#   '지다',
#   '이주연',
#   '기사',
#   '거짓',
#   '사진',
#   '글',
#   '너무',
#   '비교',
#   '되다',
#   '이주연',
#   '관종짓',
#   '을',
#   '이번',
#   '엔',
#   '크게',
#   '있다',
#   '음모',
#   '두',
#   '믿다',
#   '말다',
#   '거짓말',
#   '임',
#   '젠',
#   '발목',
#   '잡기',
#   '틀리다',
#   '복수',
#   '것',
#   '이다',
#   '팩트'],
#  ['축하'],
#  ['또',
#   '라',
#   '년',
#   '니',
#   '년',
#   '아니다',
#   '아니다',
#   '뭐',
#   '달라짐',
#   '병신',
#   '같다',
#   '년',
#   '권지용',
#   '이란',
#   '사람',
#   '연애',
#   '안되다',
#   '지금',
#   '쟤',
#   '나이',
#   '인데',
#   '그냥',
#   '팬',
#   '면',
#   '팬답',
#   '게',
#   '응원',
#   '못',
#   '해주다',
#   '망정',
#   '개또',
#   '라이',
#   '년',
#   '하여간',
#   '니',
#   '년',
#   '죄다',
#   '정신병원',
#   '처',
#   '들어가다',
#   '함'],
#  ['오다', '팬', '멋있다', '지', '디도', '멋있다', '서로', '행복하다', '바라다'],
#  ['제', '사귀다', '되다', '이다지', '디도', '잘만', '나서다', '결혼', '태양', '처럼'],
#  ['연애',
#   '어떻다',
#   '그',
#   '사람',
#   '인데',
#   '우리나라',
#   '연애',
#   '인',
#   '차다',
#   '불쌍햐',
#   '사생활',
#   '침해',
#   '너무',
#   '받다'],
#  ['스치다',
#   '간',
#   '인연',
#   '여자',
#   '연합',
#   '복수',
#   '하나',
#   '보다',
#   '돈',
#   '모으다',
#   '알바',
#   '겁나다',
#   '풀다',
#   '보다',
#   '무섭다',
#   '여우',
#   '상',
#   '여자',
#   '같이',
#   '찍다',
#   '사진',
#   '하나',
#   '없이',
#   '집',
#   '근처',
#   '가다',
#   '찍다',
#   '사진',
#   '열애설',
#   '이나',
#   '내',
#   '고아',
#   '사람',
#   '거짓',
#   '인거',
#   '다',
#   '안다'],
#  ['지다', '퇴', '물이', '라서', '재미없다'],
#  ['뭐',
#   '냐',
#   '이다',
#   '급',
#   '너무',
#   '낮다',
#   '뭐',
#   '어쩌라고',
#   '유명',
#   '배우',
#   '나',
#   '유명',
#   '아이돌',
#   '인',
#   '줄',
#   '알다',
#   '물',
#   '정도',
#   '아니다',
#   '두',
#   '물',
#   '세',
#   '물',
#   '정도',
#   '간',
#   '애',
#   '네',
#   '여자',
#   '진짜',
#   '이름',
#   '첨',
#   '들다',
#   '봄'],
#  ['엑소', '안되다', 'ㅠ'],
#  ['새해',
#   '이다',
#   '저',
#   '양반',
#   '사귀다',
#   '말다',
#   '그건',
#   '저',
#   '양반',
#   '사정',
#   '이고',
#   '여러분',
#   '작년',
#   '수고',
#   '많이',
#   '올',
#   '한해',
#   '모두',
#   '평범하다',
#   '살다',
#   '년',
#   '을',
#   '맞이',
#   '우리',
#   '모두',
#   '소원',
#   '그저',
#   '평범하다',
#   '살다',
#   '호상',
#   '이다'],
#  ['그',
#   '네',
#   '시절',
#   '연예인',
#   '열애설',
#   '나다',
#   '그네',
#   '무언',
#   '갈다',
#   '덮다',
#   'ㅋ',
#   'ㅈㄹ',
#   '나',
#   '이다',
#   '뭘',
#   '숨다',
#   '터뜨리다'],
#  ['주연',
#   '너무',
#   '아깝다',
#   '정말',
#   '예쁘다',
#   '만날',
#   '때',
#   '힐',
#   '못',
#   '신다',
#   '단화',
#   '만',
#   '신어',
#   '야',
#   '되다',
#   '아니다',
#   '남자',
#   '안되다',
#   '최소한',
#   '늘다',
#   '넘다',
#   'ㅉㅉ'],
#  ['문', '재앙', '정권', '이번', '엔', '또', '뭘', '숨다'],
#  ['지드래곤', '현', '대한민국', '연예인', '탑', '라', '생각'],
#  ['새끼',
#   '누',
#   '군',
#   '진',
#   '모르다',
#   '일부러',
#   '월',
#   '일',
#   '터뜨리다',
#   'ㅋㅋ',
#   '그리고',
#   '남성은',
#   '출신',
#   '대학',
#   '경제력',
#   '여자',
#   '나이',
#   '얼굴',
#   '가슴',
#   '평가',
#   '것',
#   '이다'],
#  ['이준', '누구', '야', '배우', '라는', '디', '누구', '지', '전소민', '덕분', '이름', '알리다'],
#  ['거', '욕', '아니다', '이준', '씨', '열애설', '한번', '나서다', '우결', '종료', '되다', '않다'],
#  ['여자', '가슴', '사이즈', '남편', '경제력', '상관관계', '있다', '연구', '결과', '있다'],
#  ['이준', '오연서', '껀데', 'ㅠㅠ'],
#  ['이준', '전소민', '낳다', '쥐다', '이주현', '낳다'],
#  ['정부', '에서', '뭔가', '숨다', '터뜨리다', '거', '랑께요', '빼앧'],
#  ['광수', '버리다', '이준', '한테', '가다', '건가', '런닝맨', '에서', '케미', '오진', '대'],
#  ['정소민', '별로', '덴', '이름', '바꾸다', '재수없다', '년', '닮다', '기분', '나쁘다'],
#  ['정소민', '초', '대박', '스타', '되다', '인생', '꼬엿', '네'],
#  ['에이', '그', '정소민', '이제야', '겨우', '런닝맨', '주목', '받다', '열애설', '터지다'],
#  ['존못', '커플'],
#  ['촛불', '들다', '정신', '나가다', '놈'],
#  ['지', '디', '비다', '너무', '급', '떨어지다'],
#  ['난', '왜', '안', '어울리다', '같다'],
#  ['이준', '군대', '안', '가다', '소', '민', '넘다', '아깝다'],
#  ['정소민', '가슴', '크다', '예쁘다'],
#  ['여자', '비주', '얼'],
#  ['소', '민', '너무', '아깝다', '가르다', '소', '민', '너', '입술', '로'],
#  ['오연서', '랑', '우결', '쓰다', '오연서'],
#  ['이다', '폐', '악질', '을', '덮다', '정도', '론', '약하다'],
#  ['역시', '설현', '미만', '잡', '이네'],
#  ['윤현민',
#   '이준',
#   '까지',
#   '대',
#   '다나',
#   '다',
#   '암튼',
#   '행쇼',
#   '오로라공주',
#   '부터',
#   '런닝맨',
#   '까지',
#   '되다',
#   '다행',
#   '이우'],
#  ['너무',
#   '부럽다',
#   '네',
#   '여',
#   '이준',
#   '오빠',
#   '돈',
#   '두',
#   '엄청',
#   '많다',
#   'ㅠ',
#   '휴',
#   '남친',
#   '그렇지만',
#   '남자',
#   '이상하다',
#   '지다',
#   '들차다',
#   '쓰다',
#   '아무렇다',
#   '않다',
#   '쓰다',
#   '왜',
#   '백',
#   '사주',
#   '아깝다',
#   '남자',
#   '에게',
#   '차갑다',
#   '자존심',
#   '듯이',
#   '여자',
#   '에게는',
#   '백이',
#   '자존심',
#   '이라',
#   '고요'],
#  ['저', '날', '반하다', '보다', '전소민', '한쪽', '가슴', '보이다', '되게', '야하다', '입다'],
#  ['이준', '노', '양심', '이네', '이르다', '엠블랙', '나갛', '나'],
#  ['지다', '커플', '한테', '밀리다'],
#  ['척척', '찍', '응애'],
#  ['야', '얼굴', '커서', '배수지', '랑', '닮다', 'ㅋㅋㅋㅋ'],
#  ['어쩌', '라는', '거지', '나', '랑', '뭔', '상관'],
#  [],
#  ['이준', '비호감'],
#  ['이준', '못', '생기다', '정소민', '불쌍'],
#  ['누', '군', '진', '모르다', 'ㅇㅋ'],
#  ['이준', '아깝다'],
#  ['연예계',
#   '동물',
#   '왕국',
#   '맞다',
#   '한낮',
#   '조연',
#   '나부랭이',
#   '연기',
#   '안',
#   '하고',
#   '연기',
#   '답시고',
#   '여자',
#   '나',
#   '꼬셔',
#   '서',
#   '지다',
#   '군대',
#   '가다',
#   '욕구',
#   '풀이',
#   '로',
#   '한번',
#   '씩',
#   '여자',
#   '곰신',
#   '만들다'],
#  ['전소민',
#   '인',
#   '줄',
#   '알',
#   '고',
#   '놀래다',
#   '꼴뚜기',
#   '같이',
#   '생기다',
#   '열애설',
#   '이냐',
#   '다스',
#   '누구',
#   '꺼',
#   '냐'],
#  ['근데', '이준', '덜', '떨어지다', '애', '아니다', '김종민'],
#  ['정소민', '아깝다'],
#  ['설현', '미만', '잡'],
#  ['이준', '돈', '쓰다', '쪼', '자다', '소문', '낫다'],
#  ['이준', '취향', '독특하다'],
#  ['이준', '짜다', '돌이', '명품', '사다', '줄', '알다', '정소민', '사다'],
#  ['정소민', '솔직하다', '연예인', '이쁘다', '않다'],
#  ['친딸',
#   '고준희',
#   '때리다',
#   '죽이다',
#   '낄낄대다',
#   '프라모델',
#   '인스타',
#   '올리다',
#   '가족',
#   '여행',
#   '다니다',
#   '이웃',
#   '딸',
#   '생일',
#   '먹여주다',
#   '남다',
#   '거',
#   '라며',
#   '미역국',
#   '돌리다',
#   '경찰서',
#   '가다',
#   '나',
#   '딸',
#   '없다',
#   '못',
#   '사다',
#   '내',
#   '딸',
#   '찾다',
#   '달라',
#   '울부짖다',
#   '친부',
#   '고병식',
#   '전라디언',
#   '오유',
#   '루리웹',
#   '회원',
#   '폭동',
#   '을',
#   '민주화',
#   '운동',
#   '이라고',
#   '날조',
#   '미화',
#   '홍보',
#   '민주',
#   '노총',
#   '금속노조',
#   '원',
#   '좋아하다',
#   '음식',
#   '홍어',
#   '일본술',
#   '정치성향',
#   '문재인',
#   '김대중',
#   '노무현',
#   '지지',
#   '하고',
#   '박근혜',
#   '이명박',
#   '증오',
#   '그렇다',
#   '보다',
#   '이준',
#   '부모',
#   '전라도',
#   '이고',
#   '박근혜',
#   '탄핵',
#   '구속',
#   '하고',
#   '문재인',
#   '집권',
#   '시키다',
#   '자다',
#   '촛불시위',
#   '이준',
#   '고병식',
#   '유사',
#   '점',
#   '많다'],
#  ['헐다', 'ㅋㅋ', '뭔가', '안', '어울리다'],
#  ['이르다', '헤어지다', '정소민', '만', '불쌍하다', '지다', '아니다'],
#  ['떡', '중', '이라', '헤라'],
#  ['이준',
#   '결별',
#   '총',
#   '맞다',
#   '죽',
#   '을',
#   '듯',
#   '그렇게',
#   '참고',
#   '참다',
#   '하필',
#   '얘',
#   '라니',
#   '얘',
#   '결별',
#   '총',
#   '쏘다',
#   '애',
#   '인데'],
#  ['여자', '존못', '인데'],
#  ['부럽다',
#   '나다',
#   '불과',
#   '달전',
#   '까진',
#   '허니문',
#   '베이비',
#   '꿈꾸다',
#   '이제',
#   '다',
#   '부질없다',
#   '당연하다',
#   '순결하다',
#   '믿다',
#   '그래서',
#   '첫날',
#   '밤',
#   '까지',
#   '기다리다',
#   '주다',
#   '배신',
#   '감',
#   '만',
#   '듭니',
#   '다',
#   '첫날',
#   '밤',
#   '와이프',
#   '피',
#   '안',
#   '흘리다',
#   '처가',
#   '집',
#   '식구',
#   '일부러',
#   '절',
#   '속이다',
#   '생각',
#   '화도',
#   '나다',
#   '어제',
#   '처가',
#   '지다',
#   '안',
#   '가다',
#   '혼자',
#   '울',
#   '고',
#   '가다',
#   '오다',
#   '지금',
#   '까지',
#   '한마디',
#   '안해',
#   '요',
#   '이혼',
#   '하고',
#   '싶다'],
#  ['오다',
#   '문재인',
#   '정부',
#   '뭘',
#   '덮다',
#   '이주연',
#   '정소민',
#   '까지',
#   '빵빵',
#   '터',
#   '트리',
#   '네',
#   '요하',
#   '지만',
#   '깨',
#   '시민',
#   '이렇다',
#   '저',
#   '질',
#   '스러운',
#   '연예인',
#   '돌려막기',
#   '현혹',
#   '되다',
#   '않다',
#   '무한'],
#  ['너무', '안', '어울리다'],
#  ['아줌마', '뉴규'],
#  ['뭐', '비리', '덮다', '터지다', '새해', '부터', '뭔', '기사', '이리', '터', '트리', '지'],
#  ['정소민', '아깝다'],
#  ['머리', '크다', '사기꾼', '언플쩌', '네'],
#  ['이준', '동물', '왕국', '들어가다'],
#  ['예쁘다', '않다', '아이린', '미만', '잡'],
#  ['누가',
#   '먼저',
#   '냐',
#   '이준',
#   '이냐',
#   '지드래곤',
#   '이냐',
#   '기레기',
#   '자기',
#   '께',
#   '먼저',
#   '라고',
#   '난리',
#   '네',
#   'ㅋ',
#   '관심',
#   '없다'],
#  ['신년',
#   '인데',
#   '뭘또',
#   '가리다',
#   '열애설',
#   '을',
#   '터',
#   '트리',
#   '늘다',
#   '국정원',
#   '정신',
#   '나',
#   '갓',
#   '냐',
#   '일',
#   '이따',
#   '구로',
#   '밖에',
#   '못',
#   '이제',
#   '일',
#   '제대로',
#   '아직도',
#   '박',
#   '그네',
#   '수족',
#   '남다'],
#  ['얘', '네', '나', '지', '디나', '솔직하다', '예상', '수', '있다', '거', '라', '놀라다', '않다'],
#  ['이병헌',
#   '송혜교',
#   '차다',
#   '어울리다',
#   '커플',
#   '이다',
#   '공개',
#   '연애',
#   '미치다',
#   '짓',
#   '이야',
#   '영원하다',
#   '같다'],
#  ['일도', '안', '지나다', '깨지다', '손', '모가지', '건', '다'],
#  ['전소민',
#   '오다',
#   '꾸다',
#   '몸매',
#   '좋다',
#   '정소민',
#   '아니다',
#   '않다',
#   '그래도',
#   '군신',
#   '분',
#   '이니',
#   '년',
#   '동안',
#   '찰지다',
#   '축하'],
#  ['연예인',
#   '기사',
#   '댓글',
#   '자다',
#   '안',
#   '달',
#   '지만',
#   '그래도',
#   '너무하다',
#   '아니다',
#   '남친',
#   '연락',
#   '죽다',
#   '안',
#   '받다',
#   '잠수',
#   '이별',
#   '그게',
#   '이준',
#   '때문',
#   '이다',
#   '남',
#   '눈',
#   '눈물나다',
#   '내',
#   '눈',
#   '에는',
#   '피',
#   '눈물',
#   '나요',
#   '소',
#   '민씨',
#   '어차피',
#   '댓글',
#   '묻히겄',
#   '지'],
#  ['힝', '이번', '생', '첨', '이라', '에서', '이민기', '랑', '차다', '어울리다', '뎅'],
#  ['준'],
#  ['뭘', '덮다'],
#  ['응', '금방', '헤어지다'],
#  ['찢어지다', '안', '어울리다'],
#  ['비급', '비급', '끼리', '만나다', '저런', '크다', '풀이', '그래도', '결혼', '확율', '높다'],
#  ['별로', '누구', '랑', '사귀다', '궁금하다', '안다', '새끼'],
#  ['동물의왕국'],
#  ['김현중', '그녀', '야', '냐', '아니다'],
#  ['남자', '비호감'],
#  ['정소민', '누구', '요'],
#  ['아이돌', '동물', '왕국'],
#  ['그나저나', '커플', '호', '냐', '아니다', '쥐', '드래곤', '호', '냐'],
#  ['핵', '떨어지다'],
#  ['이번', '년', '도안', '결별', '기사', '나오다', '같다'],
#  ['정소민', '아깝다'],
#  ['별로',
#   '인기',
#   '없다',
#   '애',
#   '이라',
#   '화나다',
#   '요가',
#   '없다',
#   '지',
#   '디',
#   '화나다',
#   '투성이',
#   '더',
#   '만'],
#  ['펜션', '가다', '그', '여자', '수건', '많이', '써다', '전해', '들다'],
#  ['엠블랙', '버리다', '이준', '아'],
#  ['정부', '뭘', '또', '숨다', '새해', '부터', '열애설', '을', '터', '트릴', '끄다'],
#  ['근데',
#   '이준',
#   '군대',
#   '가다',
#   '않다',
#   '송혜교',
#   '보아',
#   '박한별',
#   '최지우',
#   '죄다',
#   '안',
#   '기다리다',
#   '끝내다',
#   '박한별',
#   '두',
#   '번',
#   '이네'],
#  ['나다',
#   '연예인',
#   '이나',
#   '법대',
#   '가야',
#   '되다',
#   '압박',
#   '지금',
#   '파지',
#   '줍다',
#   '꽃',
#   '보다',
#   '거지',
#   'ㅇㅈ'],
#  ['동물', '왕국', '에서', '또', '쌍', '암수'],
#  ['이민기', '랑', '더', '어울리다'],
#  ['뜬금', '없다', 'ㅡㅡ'],
#  ['설자리', '없다', '열애설', '이라도'],
#  ['헉', '그렇다', '소', '민'],
#  ['이준', '자기', '말', '대로', '동물', '왕국', '처럼', '헤어지다', '꿀', '재다', 'ㅋㅋㅋㅋㅋ'],
#  ['사귀다', '바쁘다', '결별', '성', '격차'],
#  ['정소민', 'ㅜㅜ', '아깝다'],
#  ['아',
#   '뭐',
#   '야',
#   'ㅋㅋㅋ',
#   '결국',
#   '이민기',
#   '같다',
#   '연륜',
#   '보단',
#   '이준',
#   '같다',
#   '비글',
#   '을',
#   '택',
#   '건가',
#   'ㅋㅋㅋ',
#   '전',
#   '티비',
#   '에서',
#   '분명',
#   '그렇게',
#   '말'],
#  ['군대', '에서는', '치마', '만', '걸치다', '여자'],
#  ['어차피',
#   '군',
#   '제',
#   '대후',
#   '헤어지다',
#   '뻔하다',
#   '스토리',
#   '아니다',
#   '그냥',
#   '욕구',
#   '충족',
#   '면회',
#   '비서',
#   '넌',
#   '제발',
#   '머리',
#   '비서'],
#  ['한창',
#   '뜨겁다',
#   '하루',
#   '에도',
#   '몇번',
#   '씩',
#   '온몸',
#   '을',
#   '불',
#   '태우다',
#   '불',
#   '태우다',
#   '때',
#   '로군',
#   '물들다',
#   '올',
#   '때',
#   '노',
#   '저',
#   '어',
#   '라고',
#   '열심히',
#   '노',
#   '저',
#   '으',
#   '소'],
#  ['부럽다',
#   '나다',
#   '불과',
#   '달전',
#   '까진',
#   '허니문',
#   '베이비',
#   '꿈꾸다',
#   '이제',
#   '다',
#   '부질없다',
#   '당연하다',
#   '순결하다',
#   '믿다',
#   '그래서',
#   '첫날',
#   '밤',
#   '까지',
#   '기다리다',
#   '주다',
#   '배신',
#   '감',
#   '만',
#   '듭니',
#   '다',
#   '첫날',
#   '밤',
#   '와이프',
#   '피',
#   '안',
#   '흘리다',
#   '처가',
#   '집',
#   '식구',
#   '일부러',
#   '절',
#   '속이다',
#   '생각',
#   '화도',
#   '나다',
#   '어제',
#   '처가',
#   '지다',
#   '안',
#   '가다',
#   '혼자',
#   '울',
#   '고',
#   '가다',
#   '오다',
#   '지금',
#   '까지',
#   '한마디',
#   '안해',
#   '요',
#   '이혼',
#   '하고',
#   '싶다'],
#  ['어뜩하다',
#   '팬',
#   '이렇다',
#   '관심',
#   '없다',
#   '이준',
#   '그렇다',
#   '치다',
#   '정소민',
#   '망햇',
#   '네',
#   '게',
#   '연예인',
#   '열애설',
#   '터지다',
#   '피',
#   '해보다',
#   '여배우',
#   '쪽',
#   '이니',
#   '쯧쯧',
#   '정소민',
#   '아깝다',
#   '뜨다',
#   '알다',
#   '이번',
#   '열애설',
#   '로',
#   '망하다',
#   '수지',
#   '열애설',
#   '터',
#   '진날',
#   '제이와이피',
#   '주식',
#   '반토막',
#   '나다',
#   '알',
#   '지',
#   '그렇다',
#   '정소민',
#   '진짜',
#   '아깝다',
#   'ㅋㅋㅋ',
#   '님',
#   '자다',
#   '아침',
#   '드라마',
#   '에서',
#   '보다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['근대', '쟤', '네', '누구', '임', '배우', '임'],
#  ['뭐',
#   '야',
#   '이준',
#   '별',
#   '론데',
#   '정소민',
#   '아깝다',
#   '하지만',
#   '연애',
#   '모습',
#   '너무',
#   '사랑스럽다',
#   '나다'],
#  ['이준', '오연서', '껀데', 'ㅜㅜ'],
#  ['정소민', '누구', '에요'],
#  ['송중기', '송혜교', '급', '돼다', '얘넨', '뭐꼬', 'ㅋㅋㅋㅋㅋ'],
#  ['정소민', '내보내다', '짜증나다', '누구', '닮다', '별로', '다'],
#  ['윤은혜', '닮은꼴', '정소민', '아니다'],
#  ['아니다', '왜', '서민', '차', '몰다', '다니다', '쪽팔리다'],
#  ['이민기', '랑', '어울리다', 'ㅠㅠ'],
#  ['년월',
#   '일',
#   '년',
#   '간교',
#   '제후',
#   '결별',
#   '서로',
#   '좋다',
#   '동료',
#   '로',
#   '남다',
#   '로',
#   '즈',
#   '아'],
#  ['둘', '다', '모르다', '런닝맨', '나오다', '소', '민', '인가', '아니다'],
#  ['침대', '위', '에선', '뜨다', '끈', '뜨다', '끈'],
#  ['나이', '틀리다', '이준', '더', '어리다', 'ㅡㅡ'],
#  ['군인', '운전', '안되다', '않다'],
#  ['군인', '운전', '금진', '데', '저', '거', '영창', '감', '인데', '국방부', '신고', '디페'],
#  ['진짜',
#   '궁금하다',
#   '그렇다',
#   '이준',
#   '씨',
#   '군복무',
#   '중',
#   '인데',
#   '그렇다',
#   '휴',
#   '가나',
#   '와도',
#   '군복',
#   '을',
#   '입다',
#   '다니다',
#   '아니다',
#   '사진',
#   '에는',
#   '사복',
#   '같다',
#   '신병',
#   '휴가',
#   '라서',
#   '그런',
#   '건가',
#   '요'],
#  ['세상', '좋아지다', '청담동', '니', '있다', '곳', '아니다', 'ㅋㅋㅋ'],
#  ['새해', '첫', '스캔들', '개', '나', '터지다', '생각', '보다', '파급', '력', '낮다'],
#  ['근데', '이준', '누구', '냐'],
#  ['넘다', '약하다', '탑', '스타', '아니다', '다르다', '풀다'],
#  ['동물', '왕국', '이구나'],
#  ['이준', '보다', '이민기', '랑', '더', '자다', '어울리다', 'ㅠ', '그래도', '이쁘다', '연애'],
#  ['남자', '보다', '여자', '좋아하다', '정소민', '결론', '예쁘다', '여자', '아니다', '사실'],
#  ['런닝맨', '걔'],
#  ['휴가', '기간', '동안', '성', '엄청', '즐기다'],
#  ['정소민', '나쁜남자', '에서', '김남길', '죽이다', 'ㅠㅡㅠ'],
#  ['이준',
#   '여친',
#   '사귀다',
#   '정말',
#   '축하',
#   '일',
#   '근데',
#   '왜',
#   '하필',
#   '정소민',
#   '인지',
#   '정소민',
#   '스캔들',
#   '많이',
#   '난',
#   '탤런트',
#   '중',
#   '명',
#   '인데',
#   '홍기',
#   '하고',
#   '헤어지다',
#   '얼마',
#   '안되다',
#   '같다',
#   '커플',
#   '오래',
#   '못',
#   '갈다'],
#  ['런닝맨', '망하다', '이광수', '전소민', '버티다'],
#  ['앞', '성관계', '확정', '샷', '아니다', '연인', '관계', '라고', '언플'],
#  ['깨끗하다', '이준', '그나마', '호감', '이다', '너마저', 'ㅠ', 'ㅠ'],
#  ['연애', '인', '드른', '다', '이르다', '이준기', 'ㄱㄱ', '개', '바람', '둥'],
#  ['문', '재앙', '보다', 'ㄷㄷㄷㄷ', '모든', '재앙', '을', '다', '덮다'],
#  ['이렇게', '종현', '오빠', '잊혀지다'],
#  ['이준',
#   '씨',
#   '별로',
#   '인지도',
#   '없다',
#   '얼굴',
#   '끄다',
#   '되다',
#   'ㅋ',
#   '누가',
#   '보다',
#   '지다',
#   '톱스타',
#   '인',
#   '줄'],
#  ['설현', '미만', '잡'],
#  [],
#  ['실망',
#   '이네',
#   'ㅋㅋ',
#   '니',
#   '연예계',
#   '동물',
#   '왕국',
#   '이라고',
#   '연예인',
#   '이랑은',
#   '절대',
#   '연애',
#   '안',
#   '니',
#   '똑같다',
#   '따다',
#   '따르다',
#   '기대하다',
#   '내',
#   '바보',
#   '지',
#   'ㅋㅋ'],
#  ['저런', '애도', '뱀다', '블', '타고', '다니다'],
#  ['게', '컨셉', '사진', '이지', '파파라치컷', '이냐', '미띤', '라이', '패치', '야'],
#  ['거', '로', '정치인', '기업', '인들', '스캔들', '덮다', '있다', 'ㅡㅡ'],
#  ['너무',
#   '부럽다',
#   '네',
#   '여',
#   '이준',
#   '오빠',
#   '돈',
#   '두',
#   '엄청',
#   '많다',
#   'ㅠ',
#   '휴',
#   '남친',
#   '그렇지만',
#   '남자',
#   '이상하다',
#   '지다',
#   '들차다',
#   '쓰다',
#   '아무렇다',
#   '않다',
#   '쓰다',
#   '왜',
#   '백',
#   '사주',
#   '아깝다',
#   '남자',
#   '에게',
#   '차갑다',
#   '자존심',
#   '듯이',
#   '여자',
#   '에게는',
#   '백이',
#   '자존심',
#   '이라',
#   '고요'],
#  ['조', '망간', '헤어지다', '말', '이나', '오다'],
#  ['군', '바리', '운전', '이라니'],
#  ['기다', '개월', '뻔하다', '뭐', '연예', '인들'],
#  ['두다',
#   '듣보다',
#   '디스패치',
#   '지',
#   '디',
#   '만',
#   '팻어',
#   '충분하다',
#   '굳이',
#   '저런',
#   '듣보다',
#   '들다',
#   '왜',
#   '패',
#   '지다'],
#  ['이민기', '랑', '이루어지다', '바랬는데'],
#  ['군대', '가면', '끝나다'],
#  ['누구', '지'],
#  ['별', '관심', '없다', '몬데', '계속', '도배', '기', '사내', '냐'],
#  ['강도', '아니다'],
#  ['듣보다', '들이다', '왜', '얼굴', '을', '가다'],
#  ['정소민', '처음', '이라서', '마지막', '회', '싸이코패스', '그', '여운', '갈다', '않다', '이미지', '좋다'],
#  ['연애', '지다', '임신', '을', '관심', '읍', '다', '이렇다', '머', '기사', '꺼리다'],
#  ['제대', '끝'],
#  ['정소민', '그간', '즐겁다', '가르다', '어흑'],
#  ['장나라',
#   '손호준',
#   '건',
#   '부탁',
#   '좋다',
#   '소식',
#   '있다',
#   '좋다',
#   '그',
#   '둘',
#   '격하',
#   '게',
#   '응원',
#   '임'],
#  [],
#  ['기린', '형', '어떻', '게', '하고', '정소민', '진짜', '성격', '이상하다', '선', '긋다'],
#  ['여러', '저러다', '핑계', '로', '곧', '결별', '표'],
#  ['사기꾼'],
#  ['데이트', '때', '밥값', '커피', '값', '티켓', '다', '정소민', '내다'],
#  ['이준', '역시', '동물의왕국', '엇네'],
#  ['군인', '차', '몰수', '있다'],
#  ['군인', '운전', '안되다', '않다'],
#  ['남녀',
#   '주인공',
#   '실제',
#   '배꼽',
#   '못',
#   '맞추다',
#   '법안',
#   '만들다',
#   '이건',
#   '뭐',
#   '죄다',
#   '그렇다',
#   'ㅉㅉ'],
#  ['이준', '씨', '연', '늘다', '어쩌구', '요'],
#  ['이건',
#   '더',
#   '노잼',
#   '약하다',
#   'ㅠㅠ',
#   '간',
#   '보지',
#   '말고',
#   '그냥',
#   '깔끔하다',
#   '기',
#   '사내',
#   '고',
#   '끝내',
#   '라'],
#  ['동물', '왕국', '이네', '년', '아'],
#  ['ㅅㅅ',
#   '겠다',
#   '삭제',
#   '되다',
#   '일이',
#   '냐',
#   '좌이버',
#   '야',
#   '초성',
#   '만',
#   '써다',
#   '삭제',
#   '되다',
#   'ㅅㅅ',
#   '가다',
#   '뭔',
#   '줄알',
#   '고',
#   '지',
#   '혼자',
#   '상상',
#   '하고',
#   '삭제',
#   '상상',
#   '세수',
#   '겠다',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['문재인', '씨', '열애설', '로', '뭘', '덮다', '시키다'],
#  ['정소민', '아깝다'],
#  ['응', '관심', '없다'],
#  ['사진', '약하다', '함'],
#  ['군인', '휴가', '중', '운전', '을', '해도', '되다'],
#  ['일', '반', '사병', '휴가', '때우다', '가능하다', '엇', '나다', '억이', '가물가물'],
#  ['헐다', '탈덕', '페북', '인스타', '언팔', 'ㅠ'],
#  ['정소민', '누구', '고', '이준', '또', '누구', '임', '나', '만', '모르다'],
#  ['도둑', '놈', '이라', '옷', '오다', '절노', 'ㅋㅋ'],
#  ['전소민', '인', '줄', '정소민', '누구', '냐', '관심', '없다', '빨리', '지', '대갈', '주연', '인정'],
#  ['댓글',
#   '성비',
#   '계집',
#   '압도',
#   '적',
#   '인거',
#   '보다',
#   'ㅉㅉ',
#   '남',
#   '사생활',
#   '이나',
#   '보고',
#   '키드',
#   '득',
#   'ㅉㅉ'],
#  ['비처럼', '휴가', '너무', '많이', '나오다', '안되다'],
#  ['군인', '운전', '가능하다'],
#  ['끄다'],
#  ['안', '가다', '되다', '오', '바'],
#  ['댓글', '머', '지', '돈', '주다', '사람', '쓸다', '같다', 'ㅋㅋ', '전', '다지', '어울리다', 'ㅋㅋ'],
#  ['왠지', '설정', '같다', '계획', '하고', '날짜', '되다', '터', '트리', '컨셉', '하고는'],
#  ['정부', '대체', '뭘', '숨다'],
#  ['정소민',
#   '이준',
#   '보다',
#   '겨우',
#   '살',
#   '아래',
#   '인데',
#   '이준',
#   '너무',
#   '손',
#   '해보다',
#   '같다',
#   '이준',
#   '같다',
#   '연예인',
#   '라면',
#   '여러',
#   '여자',
#   '만나다',
#   '대충',
#   '연애',
#   '나중',
#   '넘다',
#   '살',
#   '정도',
#   '어리다',
#   '여자',
#   '결혼',
#   '정석',
#   '이다'],
#  ['그냥', '오연서', '랑', '사', '귀지'],
#  ['이준',
#   '씨',
#   '별로',
#   '인지도',
#   '없다',
#   '그냥',
#   '얼굴',
#   '끄다',
#   '되다',
#   'ㅋ',
#   '길거리',
#   '서',
#   '알다',
#   '사람',
#   '거의',
#   '없다',
#   '껄',
#   'ㅋㅋ',
#   '누가',
#   '보다',
#   '지',
#   '주제',
#   '톱스타',
#   '인',
#   '줄'],
#  ['여자',
#   '라는',
#   '건',
#   '그냥',
#   '단지',
#   '한두',
#   '번',
#   '욕정',
#   '물',
#   '을',
#   '비우기',
#   '위',
#   '도구',
#   '지나다',
#   '않다',
#   '왜',
#   '자꾸',
#   '연애',
#   '연애',
#   '해주다',
#   '않다',
#   '눕다',
#   '힐수',
#   '없다',
#   '아니다',
#   '여자',
#   '만',
#   '에게',
#   '평생',
#   '뿌리다',
#   '싶다',
#   '다',
#   '부질없다',
#   '순간',
#   '적',
#   '감정',
#   '이다',
#   '지금',
#   '여자',
#   '아니다',
#   '죽다',
#   '같다',
#   '결국',
#   '말',
#   '그래도',
#   '지금',
#   '뿐',
#   '이다',
#   '그리고',
#   '그',
#   '순간',
#   '을',
#   '넘기다',
#   '어느덧다',
#   '눈가',
#   '주름',
#   '늘다',
#   '늙다',
#   '퇴',
#   '물의',
#   '모습',
#   '만이',
#   '눈앞',
#   '서서',
#   '나르다',
#   '갉아먹다',
#   '퇴물',
#   '만',
#   '남다'],
#  ['노출',
#   '을',
#   '못',
#   '안달',
#   '인가',
#   '평범하다',
#   '원피스',
#   '인데',
#   '한쪽',
#   '어깨',
#   '대체',
#   '왜',
#   '내리다',
#   '억지로',
#   '내리다',
#   '티나',
#   '나다'],
#  ['응', '헤어지다'],
#  ['곧', '헤어지다'],
#  ['솔직하다', '되게', '안', '어울리다', '커플', '이다', '오래', '못', '갈다'],
#  ['정소민', '바보', '남자', '깔다', '렷', '늘다', '군', '바리', '랑', '만나다'],
#  ['너', '동물', '왕국', '입성', '이냐'],
#  ['응', '지다', '미만', '잡', 'ㅋㅋ', '왠', '듣보잡', '이여'],
#  ['니',
#   '꿈',
#   '만을',
#   '위해',
#   '남다',
#   '멤버',
#   '에게',
#   '상처',
#   '만',
#   '가득',
#   '입히다',
#   '너',
#   '라서',
#   '정말',
#   '티비',
#   '에서',
#   '볼때',
#   '마다',
#   '힘들다',
#   '엠블랙',
#   '결국',
#   '너',
#   '보단',
#   '성공하다',
#   '못',
#   '그룹',
#   '이니까',
#   '사람',
#   '지금',
#   '배우',
#   '로',
#   '성공하다',
#   '니',
#   '모습',
#   '만',
#   '보다',
#   '그래서',
#   '차다',
#   '원망',
#   '스럽다',
#   '그래도',
#   '예전',
#   '좋아하다',
#   '너',
#   '라서',
#   '새해',
#   '이렇게',
#   '사생활',
#   '공개',
#   '되다',
#   '차다',
#   '안타깝다',
#   '좋다',
#   '사람과',
#   '예쁘다',
#   '연애',
#   '바',
#   '래'],
#  ['뭐', '아쉽다', '이준', '같다', '애'],
#  ['이준', '잘생기다', '임', '이특', '닮다'],
#  ['이민기', '랑', '전소민', '너무', '어울리다', '숩', '다', '그래도', '이뿌다', '사귀다'],
#  ['헐다', 'ㅋㅋ', '광수', '랑', '러브', '라인', '재밌다', '이제', '못', '보다'],
#  ['약하다', '다른', '커플', '있다', '더', '올려주다'],
#  ['이준', '오연서', '껀데'],
#  ['오래', '못', '갈다', '것', '같다', '곰신', 'ㅜㅠ', '소', '민씨', '화이팅'],
#  ['휴가', '나오다', '겁나다', 'ㅠ', '이준', '부럽다'],
#  [],
#  ['이민기', '랑', '사귀다', '알다', 'ㅎ'],
#  ['이준', '너무', '많이', '아깝다', '같다'],
#  ['결국', '이준', '동물', '왕국', '동물', '중', '하나', '이다'],
#  ['잘못', '찌찌', '나오다', '옷', '흘러내리다'],
#  ['정소민', '강', '기탄', '어울렷는데'],
#  ['직장', '동료', '끼리', '연애'],
#  ['이준', '별로', '다', '짜다', '돌이', '정소민', '피곤하다'],
#  ['축하', '하', '지만', '곧', '헤어지다'],
#  ['정소민', '아깝다', 'ㅋㅋㅋㅋ', '왜', '이준', '이랑', '사', '귀지', 'ㅋㅋㅋ'],
#  ['아니다', '재앙', '도대체', '뭘', '덮다', '이렇게', '연속', '열애설', '을', '팡팡', '터뜨리다'],
#  ['소', '민아', '그', '코', '니코니코니'],
#  ['폭풍', '발', '쏘다'],
#  ['연예', '기사', '댓글', '보다', '여자', '압도', '적', 'ㅋㅋ', '정치', '경제', '아', '몰다'],
#  [],
#  ['이준', '아깝다', 'ㅎ'],
#  ['계속', '터지다', '문죄인', '똥줄탓', '나', '보다', '종석', '살리다', '연예계', '계속', '이용'],
#  ['뭐',
#   '여',
#   '동물',
#   '왕국',
#   '이라고',
#   '깔다',
#   '땐',
#   '언제',
#   '고',
#   '결국',
#   '이준',
#   '너',
#   '똑같다',
#   '헬',
#   '조선',
#   '연예인',
#   '이다',
#   'ㅋㅋㅋ'],
#  ['전소민', '누군데'],
#  ['ㅇㅂ', '곧', '깨다'],
#  ['가수', '아이돌', '들이다', '드라마', '진짜', '배우', '기회', '놓치다', '연기', '뭐', '같이'],
#  ['정부', '무엇', '을', '묻다', '지금', '터', '트리', '걸다'],
#  ['이딴',
#   '거',
#   '말',
#   '고',
#   '정치',
#   '관심',
#   '을',
#   '가다',
#   '아랍에미리트',
#   '의혹',
#   '이나',
#   '올',
#   '리지',
#   'ㅉㅉ'],
#  ['전소민', '인', '줄'],
#  ['정소민', '눈', '낮다', 'ㅡㄷ'],
#  ['정소민', '누구', '에요', 'ㅡㅡ'],
#  ['녀',
#   '아',
#   '돈',
#   '만',
#   '진짜',
#   '많다',
#   '키',
#   '키로',
#   '대머리',
#   '배',
#   '불뚝',
#   '남자',
#   '섹시하다',
#   '않다',
#   'ㅋㅋㅋ'],
#  ['남친', '여친', '깨지다', '있다', '임'],
#  ['이준',
#   '아',
#   '놓다',
#   '군인',
#   '주제',
#   '소',
#   '민',
#   '그만',
#   '놓다',
#   '다른',
#   '남자에게',
#   '보내다',
#   '붙잡다'],
#  ['백', '일', '휴가', '라', '그동안', '참다', '폭풍', 'ㅇㅇ'],
#  ['정소민', '언뜻', '보다', '장미란', '같다', '않다'],
#  ['휴가', '때', '많다', '시간', '을', '할애', 'ㅋㅋ'],
#  ['둘', '사귀다', '말', '든', '나', '한테', '밥', '떨어지다', '돈', '떨어지다'],
#  ['야', '준', '니', '뮤', 'ㅠ', '동물', '왕국', '갑'],
#  ['오연서', '보다'],
#  ['이민기', '씨', '랑', '더', '어울리다'],
#  ['일이이', '면', '박동', '안', '겁나다'],
#  ['급', '낮다'],
#  ['맨날', '재앙', '터지다', '덮다', '퍼뜨렸', '네'],
#  ['친', '중정부', '에서', '무엇', '을', '감추다'],
#  ['런닝맨', '바쁘다', 'ㅎㅎ'],
#  ['정부', '뭘', '또', '숨다', '열애설', '을', '두', '건', '이나', '터뜨리다'],
#  ['정소민', '아깝다'],
#  ['둥물', '왕국'],
#  ['동물의왕국'],
#  ['전파',
#   '무기',
#   '피해자',
#   '울다',
#   '억울하다',
#   '사람',
#   '더',
#   '억울하다',
#   '만들다',
#   '마르다',
#   '니',
#   '네',
#   '인생',
#   '골로',
#   '갈다'],
#  ['일말', '상초'],
#  ['이번', '생', '처음', '이라', '재밌다', 'ㅋ'],
#  ['군', '대전', '사귀다', '전역', '후', '깨지다', '전역', '이제', '필요없다', 'ㅋㅎ'],
#  ['머', '지', '이건', '또'],
#  ['미치다', 'ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['결혼', '기사', '아니다', '곧', '헤어지다'],
#  ['몰래', '뒤', '로', '사겻엇구', '만'],
#  ['어차피', '헤어지다', 'ㅋㅋㅋㅋ'],
#  ['이준', '아깝다'],
#  [],
#  ['대다',
#   '페미니스트',
#   '국정원',
#   '쓰다',
#   '버리다',
#   '소모품',
#   '이다',
#   '지금',
#   '달콤하다',
#   '버려지다',
#   '후회',
#   '하고',
#   '불나방',
#   '페미니스트'],
#  ['순간', '런닝맨', '전소민', '인', '줄'],
#  ['줌마', '밥', '은하', '고', '댓글', '다나', '요', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['디패', '아니다', '못', '믿다'],
#  ['이준', '여자', '좋아하다'],
#  ['친구', '아니다'],
#  ['오연서'],
#  ['런닝맨', '전소민', '인', '줄', 'ㄴㅇ', '졸라', 'ㅋㅋㅋ'],
#  [],
#  ['페미니스트',
#   '년',
#   '아',
#   '그리고',
#   '조직',
#   '스토커',
#   '놈',
#   '아',
#   '여기',
#   '까지만',
#   '하자',
#   '내',
#   '국정원',
#   '이란',
#   '새끼',
#   '잡다',
#   '야하다',
#   '참다',
#   '한계',
#   '보이다'],
#  ['대다', '페미니스트', '국정원', '조직', '스토커', '개새끼', '아', 'ㅗ'],
#  ['이준',
#   '진짜',
#   '뭐',
#   '하나',
#   '터지다',
#   '디패',
#   '창선',
#   '이를',
#   '포기',
#   '연',
#   '옌',
#   '이라',
#   '왜',
#   '이번',
#   '건',
#   '못자다'],
#  ['마니빨렷겟', '네'],
#  ['정소민', '오늘', '부로', '안뇽', '이다', '전소민', '갈아타다', 'ㅋ', '다'],
#  ['윤지', '호', '이제', '일', '제대로', '시기', '제일', '안좋다', '사내', '연애'],
#  ['아이돌', '쪽', '동물', '왕국', '이다', '소리', '쳣던', '그', '분', '몸소', '실천', '하', '심'],
#  ['이준', '아깝다', '아깝다'],
#  ['힝', 'ㅠ', '왜', '하필', '그래도', '예쁘다', '날다'],
#  ['드라마', '찍다', '랬', '더니', '연애', '만', '있다'],
#  ['이르다', '신혜선', '하고', '박시후', '결혼', '얘기', '나오다', '아니다'],
#  ['정소민', '아까웡', 'ㅜ'],
#  ['정소민', '아깝다', '뷔'],
#  ['정소민', '너무', '아깝다'],
#  ['이준', '아깝다'],
#  ['친일',
#   '행각',
#   '조혜련',
#   '이명박',
#   '여자',
#   '이태임',
#   '누나',
#   '조선일보',
#   '기자',
#   '이고',
#   '매형',
#   '이명박',
#   '정권',
#   '언론',
#   '보좌',
#   '관',
#   '이다',
#   '김성주',
#   '등',
#   '이상',
#   '없이',
#   '활동',
#   '함',
#   '이하늘',
#   '이나',
#   '여타',
#   '진보',
#   '성향',
#   '연예인',
#   '베충',
#   '들이다',
#   '표적',
#   '삼다',
#   '그',
#   '흠집',
#   '을',
#   '과대',
#   '포장',
#   '하',
#   '여',
#   '인간',
#   '쓰레기',
#   '로',
#   '매도',
#   '여론몰이',
#   '다니다'],
#  ['이하늘',
#   '인성',
#   '떠들다',
#   '놈',
#   '중',
#   '이하늘',
#   '대해',
#   '제대로',
#   '알다',
#   '새끼',
#   '몇',
#   '이나',
#   '되다',
#   '어디서',
#   '주어',
#   '소리',
#   '가다',
#   '악플',
#   '이나',
#   '달다',
#   '새끼',
#   '남욕',
#   '하',
#   '기전',
#   '본인',
#   '이나',
#   '챙기다'],
#  ['꿀잼', '이다', '천방지축', '하늘', '형', '기대하다'],
#  ['별로', '안', '울리다', '기회', '주다', '욤', '오히려', '캐리'],
#  ['디오', '씨', '앨범', '나오다', '좋다', '꼭', '구매', '코', '예요'],
#  ['하늘', '오빠', '멋있다', '콘서트', '가다', '반하다', '오다', 'ㅎㅎ'],
#  ['이하늘', '싫다', '강원래', '좋아하다', '보다'],
#  ['이하늘', '뭐', '별로', '문제', '있다', '생각', '되다', '않다', 'ㅋ'],
#  ['이하늘',
#   '예전',
#   '조금',
#   '악동',
#   '분위기',
#   '이다',
#   '금은',
#   '좋다',
#   '보임',
#   '갠',
#   '적',
#   '인',
#   '의견',
#   '이다'],
#  ['니',
#   '인성',
#   '이나',
#   '신경',
#   '써다',
#   '여기',
#   '서',
#   '욕',
#   '우리',
#   '마찬가지',
#   '아',
#   '니',
#   '여',
#   '그냥',
#   '치다',
#   '보다',
#   '보기',
#   '싫다',
#   '안보',
#   '면',
#   '그만'],
#  ['이명박',
#   '정권',
#   '들어서다',
#   '쥐다',
#   '살찌다',
#   '사람',
#   '굶다',
#   '라고',
#   '적히다',
#   '티셔츠',
#   '입다',
#   '방송',
#   '출연',
#   '것',
#   '진심',
#   '멋지다',
#   '그',
#   '뒤',
#   '로',
#   '블랙리스트',
#   '로',
#   '찍히다',
#   '고생',
#   '과오',
#   '많다',
#   '조용하다',
#   '응원',
#   '다'],
#  ['보지', '않다', '벌써', '부터', '판단'],
#  ['저',
#   '불타다',
#   '청춘',
#   '프로그램',
#   '을',
#   '자주',
#   '보다',
#   '이하늘',
#   '씨',
#   '합류',
#   '정말',
#   '기대',
#   '되다',
#   '이하늘',
#   '씨',
#   '하루빨리',
#   '보다',
#   'ㅎㅎ'],
#  ['이하늘', '짱', '조음', '흥'],
#  ['불금',
#   '쇼',
#   '나오다',
#   '때',
#   '랑',
#   '성나다',
#   '물고기',
#   '출연',
#   '거',
#   '보다',
#   '분위기',
#   '흐리다',
#   '이렇다',
#   '없이',
#   '오히려',
#   '자다',
#   '녹다',
#   '들다',
#   '같다',
#   '기존',
#   '이미지',
#   '때문',
#   '그렇다',
#   '생각',
#   '같다',
#   '최근',
#   '모습',
#   '보다',
#   '사람',
#   '괜찮다'],
#  ['드디어', '보상', '받다'],
#  ['오다', '굿'],
#  ['늘다', '진정하다', '뮤지션', '이하늘', '진정하다', '리더', '응원'],
#  ['이하늘',
#   '잘못',
#   '것',
#   '많다',
#   '이명박',
#   '아들',
#   '마약',
#   '파티',
#   '의혹',
#   '있다',
#   '이태임',
#   '같다',
#   '년',
#   '비',
#   '양반',
#   '이지',
#   '문제',
#   '이하늘',
#   '진보',
#   '성향',
#   '이다',
#   '보다',
#   '이명박',
#   '정권',
#   '때',
#   '블랙리스트',
#   '에도',
#   '오르다',
#   '일베충',
#   '지속',
#   '적',
#   '인',
#   '공격',
#   '을',
#   '가하다',
#   '많다',
#   '네티즌',
#   '동화',
#   '되다',
#   '움직임',
#   '을',
#   '보이다',
#   '것',
#   '이고'],
#  ['하늘',
#   '이형',
#   '오랜',
#   '만',
#   '예능',
#   '복귀',
#   'ㅠㅠ',
#   '대환영',
#   '형님',
#   '동',
#   '서',
#   '울',
#   '터미널',
#   '에서',
#   '제',
#   '알아보다',
#   '먼저',
#   '팬',
#   '이라고',
#   '인사',
#   '드리다',
#   '바쁘다',
#   '소극',
#   '인사',
#   '받다',
#   '그게',
#   '미안하다',
#   '다시',
#   '저',
#   '한테',
#   '찾아오다',
#   '고맙다',
#   '고향',
#   '다녀오다',
#   '요하',
#   '고',
#   '인사',
#   '해주다',
#   '감동',
#   '이다',
#   '거치다',
#   '어보',
#   '이지만',
#   '인정',
#   '많다',
#   '형님'],
#  ['점점', '나이', '어리다'],
#  ['나이', '먹다', '그만큼'],
#  ['옛날',
#   '에는',
#   '잘나가다',
#   '디오',
#   '씨',
#   '제법',
#   '놀다',
#   '날',
#   '나리',
#   '하늘',
#   '알',
#   '만',
#   '사람',
#   '다',
#   '알',
#   '지',
#   '잘나가다',
#   '그때',
#   '좋다'],
#  ['재밋겟다', 'ㅡㅋㅋ'],
#  ['재미있다', '기대다', '요'],
#  ['난', '기대다', '고', '재밌다', '같다', '클릭', '왜', '이렇다'],
#  ['불청', '안보', '고', '있다', '디오', '씨', '광팬', '이라', '보다', 'ㅋㅋ'],
#  ['발정',
#   '난',
#   '이혼',
#   '남녀',
#   '노',
#   '총가',
#   '노처녀',
#   '짝짓기',
#   '프로그램',
#   '거',
#   '사랑',
#   '스튜디오',
#   '되다',
#   '아니다'],
#  ['자기',
#   '성격',
#   '대로',
#   '각',
#   '자사',
#   '거지',
#   '죄',
#   '만',
#   '안다',
#   '되다',
#   '아니다',
#   '이하늘',
#   '멋있다',
#   '솔',
#   '끄다',
#   '완전',
#   '멋지다',
#   '짱',
#   '콘서트',
#   '에서',
#   '한물가다',
#   '가수',
#   '삶',
#   '이란',
#   '이건',
#   '가하다',
#   '아주',
#   '오래',
#   '동안',
#   '반짝이다',
#   '사실',
#   '을',
#   '잊다',
#   '않다',
#   '꼭',
#   '행복하다',
#   'ㅎ'],
#  ['방송', '중', '주먹질', '듯'],
#  ['재다', 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['이하늘', '잼', '잇다', '나', '이분', '웃기다', 'ㅋ', '뽯팅', '이하늘'],
#  ['근데', '이하늘', '들어오다', '분명', '재밌다', '짐', '합류', '대환영'],
#  ['하늘', '이형', 'ㅋㅋㅋㅋㅋ', '형', '왜', '거기', '서', '나오다', 'ㅋㅋ'],
#  ['불청', '아니다', '미우다', '새', '아니다'],
#  ['이하', '생각나다', '붙이', '지', '못', '편지'],
#  ['불타다', '청춘', '출연', '을', '추카'],
#  ['이명박',
#   '정권',
#   '들어서다',
#   '쥐다',
#   '살찌다',
#   '사람',
#   '굶다',
#   '적히다',
#   '티셔츠',
#   '입다',
#   '방송',
#   '출연',
#   '것',
#   '기억나다',
#   '그',
#   '뒤',
#   '로',
#   '이명박',
#   '정권',
#   '블랙리스트',
#   '오르다',
#   '지난번',
#   '촛불집회',
#   '때',
#   '음악',
#   '만들다',
#   '촛불',
#   '응원',
#   '베충',
#   '들다',
#   '눈엣',
#   '가시',
#   '같다',
#   '존재',
#   '그래서',
#   '나',
#   '이하늘',
#   '좋다',
#   '응원',
#   '다'],
#  ['기대', '말', '만', '조심하다', '화이팅'],
#  ['이하늘',
#   '악플러',
#   '시르다',
#   '당하다',
#   '이유',
#   '일베',
#   '성향',
#   '네티즌',
#   '못',
#   '일',
#   '을',
#   '지속',
#   '적',
#   '강조',
#   '하고',
#   '되새기다',
#   '안좋다',
#   '여론',
#   '을',
#   '유도',
#   '때문',
#   '임'],
#  ['이서진', '합류', 'ㅋㅋㅋㅋ'],
#  ['이하늘', '전성기', '때', '인기', '캐다', 'ㅜㅜ', '랩퍼', '스카이', '그리다'],
#  ['음', '다시', '검토', '부탁', '하늘', '이형', '팬', '이지만', '그렇다', '성향', 'ㅜㅜ'],
#  ['불청',
#   '망하다',
#   '않다',
#   '이연수',
#   '씨',
#   '출연',
#   '시청률',
#   '보장',
#   '되다',
#   '전국',
#   '아',
#   '재',
#   '을',
#   '앞',
#   '끌다',
#   '모으다',
#   '이연수',
#   '씨'],
#  ['베충',
#   '들이다',
#   '진보',
#   '성향',
#   '연예',
#   '인들',
#   '표적',
#   '삼다',
#   '악플',
#   '주도하다',
#   '경우',
#   '너무',
#   '많다',
#   '강호동',
#   '같다',
#   '놈',
#   '탈세',
#   '하고도',
#   '방송',
#   '활동',
#   '왕성'],
#  ['송혜교', '랑', '친하다', '실화', '임', '지', '금도', '친하다'],
#  ['한국', '힙합', '세대'],
#  ['불청',
#   '야',
#   '기존',
#   '멤버',
#   '물',
#   '갈이',
#   '치와와',
#   '개',
#   '커플',
#   '하차',
#   '어떻다',
#   '결혼',
#   '나가다',
#   '일',
#   '없다',
#   '김국진',
#   '결혼',
#   '맘',
#   '아예',
#   '없다',
#   '보이다',
#   '사람',
#   '이라도',
#   '하차',
#   '시키다'],
#  ['우리나라',
#   '힙합',
#   '세대',
#   '다',
#   'ㅡㅡ',
#   '음악',
#   '적',
#   '으론',
#   '끄다',
#   '디오',
#   '씨',
#   '집도',
#   '올',
#   '해안',
#   '나오다'],
#  ['년', '그냥', '좌파', '다', '꼽아주', '네', 'ㅋ', '년'],
#  ['정권',
#   '바뀌다',
#   '시',
#   '덥다',
#   '좌파',
#   '연예인',
#   '다',
#   '밀다',
#   'ㅋㅋ',
#   '내',
#   '로남불',
#   '이다',
#   '진짜',
#   'ㅋㅋ'],
#  ['낚시', '형제', '보다', '있다'],
#  ['힘내다',
#   '하늘',
#   '이형',
#   '기',
#   '죽지',
#   '말고',
#   '형',
#   '모습',
#   '을',
#   '보여주다',
#   '진심',
#   '통한',
#   '다',
#   '아자',
#   '아자'],
#  ['오', '바', '야'],
#  ['왜', '뭐', '때문', '분위기', '만', '작살', '날', '것', '같다', 'ㅎ'],
#  ['불청', '여', '자연', '인도', '참신하다', '바꾸다', '때'],
#  ['래퍼', '스카이'],
#  ['하늘', '먹다', '먹다', '보다', '자네'],
#  ['셀프', '블랙리스트', '오르다', '분', '방송', '을', '나오다', '경배'],
#  ['이하늘', '세대', '다른', '느낌'],
#  ['천하',
#   '무적',
#   '토요일',
#   '년때',
#   '여친',
#   '잇다',
#   '엇',
#   '잖다',
#   '애칭',
#   '모과',
#   '라고',
#   '헤어졋',
#   '나',
#   '헤어졋으',
#   '니',
#   '불청',
#   '나오다'],
#  ['하늘', '보단', '재', '용이', '더', '적응', '자다'],
#  ['ㅋㅋㅋ', '아', '왜', 'ㅋㅋㅋㅋ'],
#  ['줜', '나', '안', '어울리다'],
#  ['헛랄', '이라고', '봄'],
#  ['프로그램',
#   '모방',
#   '만들다',
#   '나혼자산다',
#   '되다',
#   '그걸',
#   '따르다',
#   '만들다',
#   '색다르다',
#   '걸',
#   '재미',
#   '느끼다'],
#  ['양', '아치'],
#  ['디오', '씨', '핸드볼', '경기장', '에서', '자주'],
#  ['문재인', '충성', '파', '열', '라', '밀다', '이렇다', '특혜', '지'],
#  ['실검', 'ㅋㅋㅋㅋ', '위', '예약', 'ㅋㅋㅋㅋㅋㅋ'],
#  ['미치다', '아니다'],
#  ['모자', '벗다', '대다'],
#  ['이하늘',
#   '씨',
#   '당신',
#   '뭐',
#   '대단하다',
#   '사람',
#   '착각',
#   '하',
#   '나본',
#   '데',
#   '그냥',
#   '인간',
#   '이여',
#   '남',
#   '보단',
#   '목소리',
#   '조금',
#   '더',
#   '좋다',
#   '것',
#   '뿐',
#   '이야',
#   '꿈깨'],
#  ['모자', '벗어봥', '대가리', '꼴다', '창렬', '스럽지', '안남', 'ㅋㅋㅋ'],
#  ['김완선', '하차', '라', '길', '래', '안', '보다', '결심', '되다'],
#  ['따다', '모르다', '신지', '한테', '행동', '그냥', '생', '양', '짓'],
#  ['건',
#   '모형',
#   '수',
#   '홍',
#   '이형',
#   '그리고',
#   '이하늘',
#   '셋',
#   '나이',
#   '안',
#   '맞다',
#   '제일',
#   '철',
#   '없다',
#   '보이다',
#   '연예인',
#   '중',
#   '하나'],
#  ['양준혁', '이나', '섭외', '해보다', '박재홍', '이랑', '케미', '재밌다', '같다'],
#  ['출연자', '물', '갈이', '필요하다', '싯점', '이지만', '그래도', '그렇다'],
#  ['형', '형', '누나', '누나', '앵', '알', '앵', '알', '거리', '거', '거리', '게', '보기', '싫다'],
#  ['강태공', '이하늘', '화이팅', '이다'],
#  ['앨범', '왜', '안내', '요', 'ㅜㅜ', '내다', '대박나다'],
#  ['언', '제적', '이하늘', '이여'],
#  ['국진', '옹이', '있다', '괜찮다'],
#  [],
#  ['완전', '애', '청장', '인데', '이하늘', '나오다', '안', '보다'],
#  ['재밌다', '기대하다', '사람', '왜', '이렇게', '머', '라고'],
#  ['헐다', '나오다'],
#  ['비호감'],
#  ['섭외', '창렬', '스럽다'],
#  ['솔직하다', '살', '양', '아가', '왜', '필요하다'],
#  ['사기', '공무원', '이냐', '그만', '치다', '해', '라'],
#  ['그나마',
#   '외모',
#   '꼬꼬',
#   '마',
#   '같다',
#   '보다',
#   '이하늘',
#   '이란',
#   '이름',
#   '전',
#   '나',
#   '오글거리다',
#   '네',
#   '이름',
#   '지',
#   '을',
#   '때',
#   '세',
#   '시대',
#   '참고',
#   '하고',
#   '지다'],
#  ['이하늘',
#   '양',
#   'ㅇ',
#   '치의',
#   '대표',
#   '주자',
#   '근데',
#   '쥐',
#   '잡다',
#   '티셔츠',
#   '입다',
#   '나오다',
#   '갑자기',
#   '개념',
#   '연예인',
#   '등',
#   '극',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '좌',
#   '좋다',
#   '들다',
#   '저런',
#   '사람',
#   '을',
#   '빨다',
#   '차다'],
#  ['여기다',
#   '갈수록',
#   '초심',
#   '없어지다',
#   '강수지',
#   '에게는',
#   '모든',
#   '출연자',
#   '눈치',
#   '보고',
#   '보이다',
#   '함강',
#   '수지',
#   '김국잔',
#   '한번',
#   '씩',
#   '빠지다',
#   '안해',
#   '고',
#   '불편하다',
#   '요즘',
#   '자다',
#   '안',
#   '보다'],
#  ['불타다', '깡패'],
#  ['트러블', '필요하다', '이건', '아니다'],
#  ['연예계', '은퇴', '하', '신분', '인데', '말장난', '하나', '년도', '답', '네'],
#  ['그냥', '양', '아치'],
#  ['불청', '애', '청자', '인데', '요안', '보다'],
#  ['내', '마음', '대상', '수지'],
#  ['연애', '게', '게이', '커플', '많다', '왜', '저러다', '의심스럽다'],
#  ['수지', '그거', '좋다'],
#  ['엄기준', '카리스마', '없다'],
#  ['상', '못', '받다', '열', '받다', '자다', '대상', '타다', '약', '올리다'],
#  ['지성', '어이없다'],
#  ['글쎄', '피고인', '에서', '엄기준', '연기', '너무', '연기', '같이', '별', '루', '이다'],
#  ['이종석', '수지', '최우수상', '엄기준', '꽝', '이렇다', '적폐'],
#  ['도대체',
#   '상주',
#   '기준',
#   '뭐',
#   '냐',
#   '이종석',
#   '배수지',
#   '상',
#   '받다',
#   '걸',
#   '로',
#   '보다',
#   '시청률',
#   '인기',
#   '소속사',
#   '빨',
#   '청소년',
#   '연기상',
#   '그렇다',
#   '초인',
#   '가족',
#   '이라는',
#   '드라마',
#   '있다',
#   '모르다',
#   '언니',
#   '살다',
#   '홍시',
#   '훨'],
#  ['솔직하다',
#   '개인',
#   '적',
#   '수지',
#   '랑',
#   '이종석',
#   '최우수상',
#   '받다',
#   '건',
#   '의외',
#   '이다',
#   '연기력',
#   '나쁘다',
#   '않다',
#   '우수상',
#   '받다',
#   '배우',
#   '보다',
#   '것',
#   '같다',
#   '않다'],
#  ['서브', '무슨', '대상', '이냐'],
#  ['지성',
#   '술',
#   '말다',
#   '자고',
#   '때',
#   '가다',
#   '곳',
#   '있다',
#   '어딘지아',
#   '냐',
#   '지성',
#   '빠레',
#   'ㅋㅋㅋㅋ',
#   '엌',
#   'ㅋㅋㅋㅋㅋㅋㅈㄴ',
#   '웃기',
#   '넼',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '연',
#   '예',
#   '대상',
#   '급',
#   '인지',
#   '용'],
#  ['판사', '판', '주인공', '상', '못', '받다', '것', '해안', '간', '다', '연기', '정말'],
#  ['이종석', '수지', '같다', '사람', '말고', '엄기준', '같다', '사람', '주요', '부', '믄', '으'],
#  ['수', '지', '이종석', '최우수', '그거', '하나로', '얼마나', '거지같다', '시상식', '인지', '인증'],
#  ['이종석',
#   '이랑',
#   '수지',
#   '상',
#   '주',
#   '려고',
#   '월화',
#   '수목',
#   '이따',
#   '구로',
#   '나누다',
#   '임',
#   '서현진',
#   '이랑',
#   '엄기준',
#   '못',
#   '받다',
#   '당',
#   '잠사',
#   '시청률',
#   '받다',
#   '장난',
#   '치',
#   '나',
#   'ㅋㅋㅋ'],
#  ['촤', '민호', '근데', '이보영', '빨갛다', '루즈', '검다', '시스루', '너무', '색시'],
#  ['상',
#   '정말',
#   '자다',
#   '사람',
#   '타다',
#   '되다',
#   '수',
#   '지',
#   '이종석',
#   '최우수상',
#   '엄기준',
#   '수',
#   '지',
#   '이종석',
#   '보다',
#   '못',
#   '건가',
#   '이르다',
#   '왜',
#   '방송',
#   '하나',
#   '기내',
#   '끼리',
#   '자체',
#   '적',
#   '방송',
#   '내보내다',
#   '짜증나다'],
#  ['엄기준', '차', '민호', '캐릭터', '로', '얼마나', '섬뜩하다', '솔직하다', '이종석', '보다'],
#  ['다',
#   '들다',
#   '수지',
#   '최우수',
#   '받다',
#   '당',
#   '잠사',
#   '시청률',
#   '높다',
#   '상준',
#   '거',
#   '라고',
#   '칭송',
#   'ㅡㅡ',
#   '시청률',
#   '사랑',
#   '온도',
#   '더',
#   '높다',
#   '알다',
#   '그리고',
#   '인지도',
#   '엄기준',
#   '인지도',
#   '로',
#   '밀리다',
#   '배우',
#   '서현진',
#   '인지도',
#   '로',
#   '밀리다',
#   '배우',
#   '어이',
#   '없다',
#   '당',
#   '장사',
#   '최고',
#   '시청',
#   '룰',
#   '퍼',
#   '예요'],
#  ['다해', '들다', '알다', '진정', '대', '상감', '있드', '나'],
#  ['이종석', '수지', '빼', '라', '정말', '극', '혐', '이다', '뭐'],
#  ['어제', '이종석', '에게', '최우', '상', '주다', '말', '되다'],
#  ['남궁민',
#   '한테',
#   '너무',
#   '뭐라다',
#   '셈',
#   '남궁민',
#   '대상',
#   '못',
#   '받다',
#   '너무',
#   '억울하다',
#   '죽다',
#   'ㅡㅡ',
#   '나다',
#   '솔직하다',
#   '엄기준',
#   '최고',
#   '캐릭터',
#   '상',
#   '밖에',
#   '못',
#   '받다',
#   '차다',
#   '어이',
#   '없다',
#   '올해',
#   '케사',
#   '에서',
#   '김',
#   '과장',
#   '남궁민',
#   '대상',
#   '못',
#   '받다',
#   '제일',
#   '어이',
#   '없다'],
#  ['내',
#   '배우',
#   '상',
#   '못',
#   '받다',
#   '아무',
#   '상관없다',
#   '배우',
#   '잡지',
#   '맙시',
#   '다',
#   '엄기준',
#   '씨',
#   '비호감',
#   '되다',
#   '함'],
#  ['솔직하다',
#   '부문',
#   '다르다',
#   '수지',
#   '이영애',
#   '제',
#   '치고',
#   '받다',
#   '만',
#   '자리',
#   '없다',
#   '남궁민',
#   '받다',
#   '이영애',
#   '못',
#   '받다',
#   '건',
#   '뭐',
#   '야'],
#  ['새해', '부터', '악플', '남기다', '불쌍하다', '인생'],
#  ['지성', '탈', '줄', '알다'],
#  ['엄기준',
#   '대상',
#   '정도',
#   '아니다',
#   '예전',
#   '악역',
#   '캐릭터',
#   '랑',
#   '너무',
#   '똑같다',
#   '식상하다',
#   '물론',
#   '연기',
#   '자다',
#   '그렇다고',
#   '최우수상',
#   '받다',
#   '남궁민',
#   '이종석',
#   '있다',
#   '이래저래',
#   '애매하다',
#   '못',
#   '받다',
#   '같다'],
#  ['옆',
#   '동네',
#   '보고',
#   '본받다',
#   '연기력',
#   '주다',
#   '가다',
#   '너',
#   '연기력',
#   '별로',
#   '인데',
#   '인기',
#   '많다',
#   '너',
#   '우수상',
#   '최우수상',
#   '대상',
#   '하',
#   '셈',
#   '하디',
#   '에서',
#   '우수상',
#   '최우수상',
#   '대상',
#   '받다',
#   '사람',
#   '보다',
#   '납득',
#   '감',
#   '왜',
#   '냐',
#   '전부',
#   '다',
#   '연기',
#   '연기자',
#   '이기',
#   '때문',
#   '늘다',
#   '정말',
#   '반성'],
#  ['진정하다',
#   '수지',
#   '최우수',
#   '면',
#   '스브스',
#   '시방',
#   '새',
#   'ㅋㅋㅋㅋㅋ',
#   '대상',
#   '주다',
#   '대상',
#   '시방',
#   '새다'],
#  ['어디서', '거지', '같다', '게', '나타나다', '상', '을', '받다', '어이', '없다'],
#  ['수지',
#   '최우수',
#   '주다',
#   '서현진',
#   '님',
#   '하나',
#   '주지',
#   '않다',
#   '엄기준',
#   '님',
#   '말',
#   '무엇',
#   '하리'],
#  ['내년',
#   '부터는',
#   '요일',
#   '로',
#   '나누다',
#   '줄',
#   '만',
#   '배우',
#   '주자',
#   '인기상',
#   '말고',
#   '수',
#   '지도',
#   '웬만큼',
#   '끄다',
#   '다만',
#   '엄기준',
#   '서현진',
#   '보다',
#   '위급',
#   '상',
#   '을',
#   '받다',
#   '문제',
#   '지'],
#  ['엄기준',
#   '진짜',
#   '연기',
#   '너무',
#   '달랑',
#   '캐릭터',
#   '상이',
#   '뭐',
#   '냐',
#   '구',
#   '너무하다',
#   '무슨',
#   '상이',
#   '인지도',
#   '냐',
#   '인기상',
#   '아니다',
#   '진짜',
#   '인기',
#   '중요하다',
#   '연기',
#   '로',
#   '평가',
#   '아니다',
#   'ㅜㅜ',
#   '진짜',
#   '엄기준',
#   '너무',
#   '연기',
#   '잘해주다',
#   '드라마',
#   '볼때',
#   '마다',
#   '빠져들다',
#   '최우수상',
#   '급',
#   '대상',
#   '급',
#   '인데',
#   '너무하다',
#   '수지',
#   '나',
#   '이종석',
#   '최우',
#   '상급',
#   '면',
#   'ㅡㅡ'],
#  ['엄기준', '을', '최우수상', '이라도', '주다', '수지', '이종석', '차다', 'ㅋㅋㅋ', '인기상', '인가'],
#  ['이종석',
#   '수지',
#   '최우수상',
#   '욕',
#   '사람',
#   '많다',
#   '상',
#   '받다',
#   '연기',
#   '충분하다',
#   '엄기준',
#   '핵심',
#   '상',
#   '못',
#   '챙기다',
#   '주다',
#   '서현진',
#   '안',
#   '오다',
#   '배척',
#   '거',
#   '그게',
#   '흠',
#   '이다',
#   '스브스',
#   '연기대상'],
#  ['김연아', '마지막', '올림픽', '때', '금메달', '뺏다', '기분'],
#  ['떵수', '지', '극혐'],
#  ['피고인',
#   '작품',
#   '되어다',
#   '김민석',
#   '상',
#   '안주',
#   '고',
#   '당',
#   '잠사',
#   '최우수',
#   '연기상',
#   '두다',
#   '가다',
#   '가다',
#   '정해',
#   '인',
#   '암',
#   '꺼',
#   '안주',
#   '고',
#   'ㅋㅋㅋㅋ'],
#  ['난', '솔직하다', '피고인', '노잼', '이다'],
#  ['지성', '너무', '멋지다', 'ㅜ'],
#  ['당',
#   '잠사',
#   '누가',
#   '뭐',
#   '래',
#   '재밌다',
#   '그때',
#   '당시',
#   '깔다',
#   '사람',
#   '없다',
#   '안',
#   '보다',
#   '들이다',
#   '상',
#   '받다',
#   '악플달다',
#   '발광하다'],
#  ['수지', '최우수상', '송승헌', '대상', '함께', '연기대상', '역대', '급', '남다'],
#  ['그래도', '연기대상', '인정', '하', '지만', '늘다', '정말', '상', '받다', '사람', '어처구니', '없다'],
#  ['이종석', '엄기준'],
#  ['여',
#   '틀다',
#   '인기',
#   '상이',
#   '다',
#   '연기',
#   '못',
#   '이종석',
#   '서다',
#   '대상',
#   '주더',
#   '니',
#   '오다',
#   '해',
#   '또',
#   '엄기준',
#   '이랑',
#   '지성',
#   '이라',
#   '공동',
#   '수상',
#   '마땅하다'],
#  ['엄기준', '거르', '고', '수지', '이종석', '최우수상', 'ㅋㅋㅋㅋㅋ', '코미디', '냐'],
#  ['역대',
#   '연예인',
#   '이경규',
#   '짱아',
#   '님',
#   '친구',
#   '자꾸',
#   '주병진',
#   '이란',
#   '사람',
#   '짱',
#   '이르다',
#   '얼토',
#   '당',
#   '토',
#   '앉다',
#   '첨',
#   '들다',
#   '봄',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['엄기준',
#   '월화',
#   '이종석',
#   '수목',
#   '수상',
#   '부문',
#   '다르다',
#   '엄기준',
#   '상',
#   '못',
#   '타다',
#   '걸',
#   '왜',
#   '이종석',
#   '한테',
#   '화',
#   '풀이',
#   '지'],
#  ['지성', '이보영', '부', '부참', '예쁘다'],
#  ['신기하다',
#   '수지',
#   '년전',
#   '엔',
#   '가도',
#   '엠빙',
#   '에서',
#   '최우수상',
#   '을',
#   '수상하다',
#   '겁니다',
#   '나문희',
#   '선생님',
#   '평생',
#   '한번',
#   '받다',
#   '그',
#   '상',
#   '을',
#   '수지',
#   '벌써',
#   '지상',
#   '파곳',
#   '을',
#   '휩쓸다',
#   '신인상',
#   '까지',
#   '패스',
# ...
#  ['난', '진짜', '재다', '폭력', '넘다', '심해', '짜증나다'],
#  ['아무리',
#   '드라마',
#   '라도',
#   '어느',
#   '정도',
#   '현실',
#   '반영은',
#   '검사',
#   '무슨',
#   '호구',
#   '아니다',
#   '깡패',
#   '검사',
#   '건드리다',
#   '좃',
#   '되다',
#   '작가',
#   '진짜',
#   '모르다',
#   'ㅋㅋㅋ'],
#  ['그나마', '재밌다', '보다', '전편', '기억', '양익준', '땜', '보다'],
#  ['검사', '건달', '이랑', '패싸움', '경찰기동대', '두다', '뭐', 'ㅎㅎ', '맨날', '피터지다', '쌈질', '이야'],
#  ['주진모', '일인', '역임', '누가', '누구'],
#  ['주인공',
#   '왜',
#   '나오다',
#   '박정훈',
#   '어재',
#   '대본',
#   '동공',
#   '지진',
#   '아니다',
#   '이해',
#   '없다',
#   '반전',
#   '이야',
#   '박중훈',
#   '그',
#   '정도',
#   '로',
#   '바보',
#   '라고',
#   '그',
#   '선배',
#   '다',
#   '알다',
#   '같다',
#   '한마디',
#   '안'],
#  ['차다', '재미없다', '안', '보다'],
#  ['편이', '너무', '재밌다', '편', '볼', '생각', '안', 'ㅡㅡ', '다행', '이라', '생각'],
#  ['무슨', '스토리', '개연', '성', '이렇게', '없다', 'ㅋㅋㅋㅋ'],
#  ['아', '완전', '재밌다', '진짜', '오씨', '엔', '감사하다'],
#  ['정석원', '너무', '멋있다'],
#  ['이제', '다시다', '안', '보다', '가다', '정답'],
#  ['차다',
#   '짜증나다',
#   '드라마',
#   '다',
#   '초반',
#   '보다',
#   '짜증나다',
#   '안',
#   '보다',
#   '나쁘다',
#   '녀석',
#   '아니다',
#   '멍청하다',
#   '녀석',
#   '만',
#   '모으다',
#   '드라마',
#   '작가',
#   '멍청하다',
#   'ㅋㅋ'],
#  ['양익준',
#   '식상하다',
#   '똥파리',
#   '연기',
#   '언제',
#   '까지',
#   '나쁘다',
#   '놈',
#   '캐릭터',
#   '시즌',
#   '비다',
#   '너무',
#   '약하다'],
#  ['박중훈', '여기', '드라마', '캐스팅', '영', '아니다'],
#  ['뭐',
#   '야',
#   '댓글',
#   '진심',
#   '이렇게',
#   '속',
#   '시원',
#   '하고',
#   '빠르다',
#   '전개',
#   '드라마',
#   '진짜',
#   '오랫',
#   '만',
#   '인데',
#   '에피소드',
#   '중심',
#   '인',
#   '나쁘다',
#   '녀석',
#   '보다',
#   '훨씬',
#   '재밌다',
#   '카메라',
#   '흔들리다',
#   '눈좀',
#   '아프다',
#   '빼다',
#   '드라마',
#   '흠잡다',
#   '때',
#   '없다',
#   '명작',
#   '임',
#   '지금',
#   '나오다',
#   '편',
#   '까지는'],
#  ['나쁘다',
#   '놈',
#   '천지',
#   '네',
#   '아주',
#   '편',
#   '보다',
#   '훨씬',
#   '재다',
#   '편',
#   '여주',
#   '발암',
#   '연기',
#   'ㅋㅋㅋ',
#   '생각나다'],
#  ['안보',
#   '고',
#   '악플달다',
#   '보다',
#   '솔직하다',
#   '요즘',
#   '방영',
#   '드라마',
#   '중',
#   '에서',
#   '제일',
#   '재밌다',
#   '같다',
#   'ㅋㅋㅋㅋ',
#   '화',
#   '유기',
#   '못',
#   '보다'],
#  ['역시', '화', '부터', '존나', '재미없다', 'ㅋㅋㅋㅋ'],
#  ['명덕', '검사', '장이', '다', '고', 'ㅡ', 'ㅡ'],
#  ['검사', '장이', '왜', '주진모', '냐', '기자', '넘다', '정신', '안', '차리다'],
#  ['제일',
#   '웃기다',
#   '엘베',
#   '앞',
#   '에서',
#   '총',
#   '들이밀다',
#   '아가',
#   '리전',
#   '때',
#   'ㅋㅋㅋㅋ',
#   '무슨',
#   '모임'],
#  ['너무', '재미없다', '시즌', '핵', '노잼', '시즌', '다시', '보다', '중핵잼'],
#  ['스토리',
#   '짱짱하다',
#   '배우다',
#   '열',
#   '일',
#   '데',
#   '왤케',
#   '나쁘다',
#   '녀석',
#   '아니다',
#   '호구',
#   '녀석',
#   '들이다',
#   '맨날',
#   '당하다',
#   '무슨',
#   '하루',
#   '라도',
#   '이기다',
#   '본적',
#   '없다',
#   '작가',
#   '님',
#   '혹시',
#   '머',
#   '우리',
#   '같다',
#   '서민',
#   '아무리',
#   '멀다',
#   '짓',
#   '을',
#   '해도',
#   '돈',
#   '많다',
#   '재벌',
#   '못',
#   '이기다',
#   '걸',
#   '가르치다',
#   '주다',
#   '싶다',
#   '이렇게',
#   '쓰시',
#   '거',
#   '예요',
#   '너무',
#   '현실',
#   '적',
#   '이라',
#   '가슴',
#   '비수',
#   '꽂다',
#   'ㄷㄷ'],
#  ['정리', '기황후', '나오다', '주진모', '아니다', '마의', '나오다', '주', '진모임'],
#  ['주진모',
#   '두',
#   '명',
#   '이다',
#   '주진모',
#   '라고',
#   '하든',
#   '지',
#   '올드영',
#   '주진모',
#   '라고',
#   '하든',
#   '지',
#   '검사',
#   '장',
#   '김',
#   '사장',
#   '이라고',
#   '하든',
#   '지',
#   '뭔',
#   '개',
#   '소리',
#   '야'],
#  ['전형',
#   '적',
#   '인',
#   '한국',
#   '식',
#   '드라마',
#   '임',
#   '주인공',
#   '약하다',
#   '맨날',
#   '당하다',
#   '고구마',
#   '개',
#   '먹이',
#   '고',
#   '종영',
#   '직전',
#   '사이다',
#   '병',
#   '던지다',
#   '줌',
#   'ㅡㅡ'],
#  ['영화로', '만들다', '오히려', '훨씬', '나다', '듯'],
#  ['박중훈', '만', '안', '나오다', '재미', '있다'],
#  ['명득', '왜', '주진모', '입', '니까', '똑바로', '쓸다'],
#  ['시즌', '보다', '잼', '쓰다'],
#  ['이렇다',
#   '저렇다',
#   '시',
#   '애',
#   '밉다',
#   '치다',
#   '보다',
#   '그냥',
#   '보',
#   '사람',
#   '있다',
#   '그냥',
#   '스토리',
#   '어',
#   '케',
#   '해달라다',
#   '시청률',
#   '떨어지다',
#   '알다',
#   '들다',
#   '알다',
#   '여',
#   '틀다',
#   '오지랖',
#   'ㅉㅉ'],
#  ['무슨',
#   '년대',
#   '홍콩영화',
#   '찍다',
#   '불빛',
#   '빨갛다',
#   '고참',
#   '가지가지',
#   '얘',
#   '네',
#   '들다',
#   '글구',
#   '퍽함',
#   '패싸움',
#   '차다',
#   '연출',
#   '작가',
#   '꼬',
#   '라',
#   '지하',
#   '곤'],
#  ['편', '스릴', '있다', '재다', '보다', '편', '스토리', '답답하다', '넴', '아쉽다'],
#  ['드라마',
#   '현실',
#   '성',
#   '을',
#   '가다',
#   '하',
#   '니깐',
#   '작가',
#   '무리수',
#   '두다',
#   '게',
#   '현실',
#   '임',
#   '우린',
#   '보이다',
#   '믿다',
#   '믿다',
#   '싫다',
#   '부정',
#   '하',
#   '지현',
#   '정치',
#   '꾼',
#   '얘기',
#   '같다',
#   '부담',
#   '되다',
#   '더',
#   '지켜보다',
#   '렵니',
#   '다',
#   '나쁘다',
#   '녀석',
#   '정말',
#   '조폭',
#   '이나',
#   '대기업',
#   '회장',
#   '들이다',
#   '필요',
#   '없다',
#   '결국',
#   '엔',
#   '그',
#   '나쁘다',
#   '놈',
#   '뒤',
#   '에는',
#   '언제나',
#   '그앴듯',
#   '더',
#   '나쁘다',
#   '놈',
#   '정치',
#   '꾼',
#   '아니다',
#   '작가',
#   '어쩌면',
#   '정말',
#   '나쁘다',
#   '권력',
#   '이라는'],
#  ['명득', '하고', '일후', '하고', '주진모', '인역', '이란', '겨', '도대체', '몬', '글', '인지'],
#  ['정도',
#   '면',
#   '재밌다',
#   'ㅋㅋㅋ',
#   '배우',
#   '연기',
#   '반전',
#   '있다',
#   'ㅋㅋㅋ',
#   '티비',
#   '드라마',
#   '다',
#   '이렇다',
#   '뭐',
#   'ㅋㅋ',
#   '시즌',
#   '보다',
#   '스토리',
#   '훨씬',
#   '나',
#   '난',
#   '막장드라마',
#   '뭐',
#   '되다',
#   '않다',
#   '로',
#   '멘스',
#   '이런',
#   '거',
#   '보다',
#   '훨씬',
#   '낫다'],
#  ['기',
#   '사',
#   '제목',
#   '을',
#   '잘못',
#   '쓸다',
#   '듯',
#   '검사',
#   '장이',
#   '꾸미다',
#   '일',
#   '인데',
#   '뜬금',
#   '포',
#   '주진모',
#   '일후',
#   '꾸미다',
#   '기사',
#   '제목',
#   '뜨다',
#   '안',
#   '그렇다',
#   '내용',
#   '복잡하다',
#   '뎅',
#   '더',
#   '헷갈리다',
#   'ㅡㅡ'],
#  ['주진모', '언제', '부터', '검사', '장이', '되다'],
#  ['액션', '신', '화면', '흔들다'],
#  ['설명',
#   '배우',
#   '본명',
#   '쓸다',
#   '바',
#   '에는',
#   '차라리',
#   '극',
#   '중',
#   '직업',
#   '같다',
#   '걸',
#   '로',
#   '쓰다',
#   '되다',
#   '맨날',
#   '배우',
#   '본명',
#   '쓰다',
#   '더',
#   '못',
#   '알',
#   '아',
#   '먹음',
#   '배우',
#   '본명',
#   '알리다',
#   '일부러',
#   '노력',
#   '거'],
#  ['화', '인데', '내용', '거의', '화급', '인데', '아마', '또', '반전', '있다'],
#  ['주진모', '맞다'],
#  ['기사', '똑바로', '써다', '기', '자색', '아'],
#  ['믿다', '보다', '박중훈'],
#  ['이상하다', '오다', '가다', '다', '최소한', '이름', '맟', '추다', '야하다', '않다'],
#  ['드라마', '너무', '무거워', '마블리', '나오다', '때', '보다', '더하다', 'ㅜㅠ'],
#  ['비밀',
#   '숲',
#   '처럼',
#   '에피소드',
#   '쌓이다',
#   '쌓이다',
#   '게',
#   '하나',
#   '크다',
#   '모양',
#   '딱',
#   '들어맞다',
#   '나쁘다',
#   '녀석',
#   '아무',
#   '궁금증',
#   '유발',
#   '해내다',
#   '못',
#   '궁금하다',
#   '일',
#   '해결',
#   '방법',
#   '개싸움',
#   '궁금하다',
#   '일',
#   '해결',
#   '방법',
#   '개싸움',
#   '반복',
#   '결국',
#   '기대다',
#   '없다',
#   '반전',
#   '번',
#   '주다',
#   '걸',
#   '로',
#   '또',
#   '개싸움',
#   '시작',
#   '되다'],
#  ['얼마나', '한심하다', '어서', '끝내', '라'],
#  ['기자', '야', '안타깝다', '많이', '바쁘다'],
#  ['주진모', '허사', '장', '이자나', 'ㅂㅅ'],
#  ['배우',
#   '차이다',
#   '연기력',
#   '이나',
#   '모든',
#   '면',
#   '예전',
#   '마동석',
#   '김상중',
#   '비다',
#   '많이',
#   '떨어지다',
#   '같다'],
#  ['볼', '만하', '다', '역시', '박중훈', '이네'],
#  ['편이', '백퍼'],
#  ['기자', '뭘', '보고', '기사', '쓰시', '나', '제발', '기본', '적', '인', '인물', '확인'],
#  ['오타', '다', '똑바로', '써다'],
#  ['정신', '차리다', '글', '쓸다'],
#  ['주진모', '배후'],
#  ['어떻다', '주진모', '라는', '얘기', '야'],
#  ['멀다',
#   '머',
#   '지',
#   '보고',
#   '있다',
#   '답답하다',
#   '너무',
#   '기대하다',
#   '보다',
#   '회차',
#   '보고',
#   '혹시',
#   '나',
#   'ㅋㅋ',
#   '회차',
#   '중도',
#   '포기',
#   'ㅋㅋ'],
#  ['여기', '서', '주진모', 'ㅡ', '검사', '장', '을', '말함', '박중훈', '상사'],
#  ['아', 'ㅅㅂ', '제목', '스포', '당하다', 'ㅡ', 'ㅡ'],
#  ['분명하다',
#   '드라마',
#   '보고',
#   '기사도',
#   '읽다',
#   '너무',
#   '복잡하다',
#   '이해',
#   '안되다',
#   'ㅋㅋㅋㅋ',
#   '나쁘다',
#   '녀석',
#   '시즌',
#   '이랑',
#   '너무',
#   '차이나',
#   '그냥',
#   '제목',
#   '다른',
#   '거',
#   '로'],
#  ['너무', '악당', '누군지', '처음', '부터', '밝히다', '시작', '사람', '흥미', '못', '끄다'],
#  ['김새론', '김소현', '김유정'],
#  ['지희', '코좀손', '보고오다'],
#  ['베드', '신', '찍', '냐'],
#  ['어짜피', '셋', '다', '채수빈', '미모', '발림', 'ㅋㅎ'],
#  ['내',
#   '주의',
#   '이름',
#   '비슷하다',
#   '애',
#   '왜',
#   '이리',
#   '많다',
#   '비슷하다',
#   '짖다',
#   '헷갈리다',
#   '누구',
#   '좋다',
#   '그',
#   '카',
#   '고',
#   '내',
#   '한테',
#   '자기',
#   '얘',
#   '보다',
#   '달다',
#   '의도',
#   '짜증나다',
#   '시댁',
#   '친정',
#   '구미면',
#   '그',
#   '집',
#   '맡다',
#   '겠다',
#   '자꾸',
#   '애',
#   '보다',
#   '달라',
#   '고',
#   '아니다',
#   '울',
#   '딸',
#   '공',
#   '부방',
#   '보내다',
#   '뭐',
#   '보태',
#   '주다',
#   '왜',
#   '짜증',
#   '이라',
#   '지애',
#   '보다',
#   '달라',
#   '고',
#   '일부러',
#   '안',
#   '챙기다',
#   '내',
#   '너희',
#   '보모',
#   '냐',
#   '지',
#   '얘',
#   '지다',
#   '가보다',
#   '에덴',
#   '연선',
#   '이집',
#   '애',
#   '지',
#   '동생',
#   '저희',
#   '챙기다',
#   '왜',
#   '우리',
#   '시연',
#   '챙기다'],
#  ['얘', '네', '아무리', '연기', '최우수', '배우', '상', '수지'],
#  ['나', '랑', '결혼', '참고', '로', '난', '올해', '되어다', 'ㅋ'],
#  ['예쁘다', '배우', '만', '기대', '되다', '기자', '밉다', '서신애', '어디', '감'],
#  ['김유정', '이랑', '왕게임'],
#  ['농', '익다'],
#  ['느그', '얼마나', '긁다', '모으다', '빌딩', '세우다', '하니'],
#  ['일베충',
#   '메',
#   '갈다',
#   '충',
#   '사형',
#   '시키다',
#   '친일',
#   '쪽바리',
#   '근절',
#   '하고',
#   '살기',
#   '좋다',
#   '대한민국',
#   '만들다'],
#  ['이제', '얘', '성인', '이니까', '마음', '놓다', '섹', '드립', '치다', '되다', '여', 'ㅇㅅㅇ'],
#  ['이제', '오빠', '한테', '시집', '오다', '되다', 'ㅎ'],
#  ['김유정', '빼다', '김소현', '진지희', '크다', '역변', 'ㅋㅋㅋ'],
#  ['합법', '적', '가능하다', '나이', '좋다'],
#  ['먹음', '직', '스럽게', '자다', '익다'],
#  ['니', '인생', '에서', '가장', '이쁘다', '시기', '끝나다', '그래도', '까지는', '괜찮다', '실컷', '즐기다'],
#  ['뭔가', '함정'],
#  ['드디어', '유정', '합법', '적'],
#  ['드디어', '합법'],
#  ['너무', '과도', '연기자', '빨다', '식상하다'],
#  ['김새론', '갑', '이지'],
#  ['착하다', '대다', '보내다', '어리다', '부터', '많다', '인기', '거만하다', '몸', '배다', '걱정', '이네'],
#  ['김', '쏘다', '오오오오오', '이제', '스물', '돼다', '오빠', '한테', '시집', '라사', '랑', '해'],
#  ['솔', '끄다', '김새론', '모르다', '진지희', '끼다', '급', '아니다', '않다'],
#  ['유정', '이제', '이미지', '변신', '하자', '젠', '귀척', '나이', '아니다'],
#  ['서신애', '년생', '이지만', '어쩌누', 'ㅠㅠ'],
#  ['미성년',
#   '을',
#   '넘다',
#   '성인',
#   '인',
#   '스무살',
#   '되어다',
#   '인생',
#   '최고',
#   '선물',
#   '을',
#   '받다',
#   '축하',
#   '드리다',
#   '더불다',
#   '그',
#   '살',
#   '을',
#   '더불다',
#   '가장',
#   '빛',
#   '내주다',
#   '수',
#   '있다',
#   '외부',
#   '적',
#   '선물',
#   '최고',
#   '사립대',
#   '인',
#   '성균관대',
#   '학교',
#   '합격',
#   '이다',
#   '그걸',
#   '받다',
#   '못',
#   '아쉽다'],
#  ['손예진', '김태희', '살때', '지리다', '애', '네', '들다', '그냥', '일반인', '수준'],
#  ['김소현',
#   '김유정',
#   '해품달',
#   '아역',
#   '성인',
#   '이미지',
#   '로만',
#   '보다',
#   '둘',
#   '역할',
#   '바꾸다',
#   '더',
#   '어울리다',
#   '연기',
#   '김유정',
#   '더',
#   '김소현',
#   '동글동글',
#   '게',
#   '한가인',
#   '이랑',
#   '닮다',
#   '김유정',
#   '김소현',
#   '보다는',
#   '날렵하다',
#   '생기다',
#   '악역',
#   '이랑',
#   '어울리다'],
#  ['유정', '진', '소현', '갑', '이지', '빵꾸똥꾸', '연기', '자다'],
#  ['셋다별루', '김새론', '짱'],
#  ['유정', '등', '소현', '등', '지희', '끼다', '급', '달라', '서', '탈락'],
#  ['드뎌', '스물', '이다'],
#  ['서신애', '델꼬', '이쁘다'],
#  ['진지희', '크다', '사나', '닮다'],
#  ['정도', '면', '진지희', '디스', '아니냨', 'ㅋㅋㅋㅋㅋㅋ', '아지', '매', '데리다', '넼', 'ㅋㅋㅋ'],
#  ['진지희', '같이', '끼다', '레벨', '아니다', '나'],
#  ['솔',
#   '끄다',
#   '김소현',
#   '존예',
#   '고',
#   '김유정',
#   '분위기',
#   '랑',
#   '비율',
#   '깡패',
#   '고',
#   '진지희',
#   '빵꾸똥꾸'],
#  ['김유정',
#   '보다',
#   '말다',
#   '나머지',
#   '두',
#   '명',
#   '못',
#   '생기다',
#   '그리고',
#   '연기',
#   '못',
#   '애기',
#   '들이다',
#   '연기자',
#   '라고',
#   '보다',
#   '주다',
#   '그만',
#   '나와라'],
#  ['합법', '적', '담배', '필수', '있다'],
#  ['김유정',
#   '개그맨',
#   '심진화',
#   '닮다',
#   '어제',
#   '시상식',
#   '나오다',
#   '보다',
#   '옆',
#   '살짝',
#   '얼굴',
#   '돌리다',
#   '심진화',
#   '보',
#   '여서',
#   '깜놀',
#   'ㅋ',
#   '며칠',
#   '전',
#   '심진화',
#   '기사',
#   '에서도',
#   '유정',
#   '얼굴',
#   '보이다',
#   '유정',
#   '한테',
#   '서도',
#   '심진화',
#   '보이다',
#   '모르다'],
#  ['두', '천사', '일반인', '있다'],
#  ['신신애', '만', '불쌍', 'ㅠ'],
#  ['새', '론', '이다', '가다'],
#  ['진', '누구'],
#  ['유정',
#   '이하고',
#   '지희',
#   '어리다',
#   '적',
#   '부터',
#   '주인',
#   '공역',
#   '을',
#   '많이',
#   '해',
#   '서',
#   '알다',
#   '소현',
#   '해품달',
#   '에서',
#   '유정',
#   '괴롭히다',
#   '악역',
#   '역활',
#   '말고는',
#   '기억',
#   '없다',
#   '어쨌든',
#   '이쁘다',
#   '들다',
#   '크다'],
#  ['드라마',
#   '찍다',
#   '무슨',
#   '카메라',
#   '대들다',
#   '대본',
#   '쓰다',
#   '작가',
#   '있다',
#   '되다',
#   '투자자',
#   '모으다',
#   '김소현',
#   '진지희',
#   '가지',
#   '고',
#   '안되다',
#   '김유정',
#   '급',
#   '되다',
#   '가능하다'],
#  ['진지희', '소속사', '에서', '내다', '기사', '같다', '어딜', '김소현', '김유정', '비교', 'ㅋㅋ'],
#  ['와우', '드디어', 'ㅋㅋㅋ', '이제', '마음껏', '상상'],
#  ['김유정', '주연', '급', '나머지', '서브', '이유', '입체', '적', '이쁘다', '않다'],
#  ['김유정', '개', '꼴', '보기', '싫다'],
#  ['년',
#   '트로이카',
#   '김소현',
#   '김유정',
#   '진지희',
#   '셋',
#   '조금',
#   '더',
#   '지켜보다',
#   '함',
#   '특히',
#   '기대',
#   '되다',
#   '김유정',
#   '개인',
#   '적',
#   '년생',
#   '아역배우',
#   '예쁘다',
#   '수수하다',
#   '보이다',
#   '김현수',
#   '김지민',
#   '정다빈',
#   '김새론'],
#  ['김소현', '넘사벽', '김유정', '진지희', '아니다'],
#  ['서신애', '언급', '없다'],
#  ['김소현', '연기', '꼬마', '유정', '연기', '여자'],
#  ['진지희', '김소희', '홧팅', '두', '사람', '앞날', '꽃길', '만', '걸다'],
#  ['진지희', '코', '수술'],
#  ['연예',
#   '인들',
#   '이름',
#   '똑같이',
#   '헷갈리다',
#   '똑같다',
#   '이름',
#   '왜',
#   '그렇게',
#   '많다',
#   '재수없다',
#   '년',
#   '딸',
#   '생각나다',
#   '지',
#   '엄마',
#   '닮다',
#   '못',
#   '생기다',
#   '복',
#   '없다',
#   '보이',
#   '지만'],
#  ['진지희', '정말', '이쁘다', '김유정', '이랑', '비교', '안되다'],
#  ['좋다', '이제', '합법', '적', '사귀다', '있다'],
#  ['김소현', '김유정', '진지희'],
#  ['몸매', '유정', '압승'],
#  ['두번째', '오지', '네'],
#  ['우리', '유정', '갑', '이지'],
#  ['어디', '똥꾸', '빵꾸', '갖다', '붙이다', 'ㅋㅋㅋㅋ'],
#  ['유정아', '살빼다', '어제', '보다', '팔뚝', '장난', '없다'],
#  ['진지희', '셋', '중', '뭔가', '풀다', '같다', '느낌'],
#  ['미모', '순서대로', '사진', '올리다', '기자', '센스', '쩐다'],
#  ['김유정', '어제', '보다', '수영', '이랑', '닮다'],
#  ['김예림', '을', '빼다', '섭하다'],
#  ['내',
#   '친구',
#   '스타일',
#   '리스트',
#   '인데',
#   '연예인',
#   '인성',
#   '찾다',
#   '제일',
#   '바보',
#   '같다',
#   '짓',
#   '이르다',
#   '연예인',
#   '그냥',
#   '연예인',
#   '으로만',
#   '보다',
#   '인성',
#   '찾다',
#   '말고'],
#  ['김소현',
#   '젤',
#   '낫다',
#   '김유정',
#   '이나',
#   '진지희',
#   '쌍',
#   '팔',
#   '년도',
#   '에나',
#   '먹히다',
#   '얼굴',
#   '임'],
#  ['김', '유전', '일부러', '살찌다', 'ㅋㅋㅋ', '한류', '배우', '소현', '비주', '얼', '최고', '지'],
#  ['저', '중', '김유정', '제일', '이쁘다', '김유정', '흥', '래', '라', '이쁜이'],
#  ['지희', '젤', '이쁘다', '안질리다', '얼굴', '이야'],
#  ['명', '급', '많이', '떨어지다', '뎁'],
#  ['김유정', '차렷'],
#  ['사진', '미모', '순이', '네', '김소현', '김유정', '진지희'],
#  ['좋다',
#   '인상',
#   '가지다',
#   '사람',
#   '이다',
#   '김유정',
#   '남다',
#   '강',
#   '다니엘',
#   '당',
#   'ㅋㅋㅋ',
#   '이쁘다',
#   '공',
#   '차카',
#   '게',
#   '생기다',
#   '엉',
#   '두다',
#   '넘다',
#   '조앙',
#   '히힛'],
#  ['셋', '중', '진지희', '젤', '똑똑하다', '맘씨', '예쁘다', '연기', '생각'],
#  ['여기',
#   '김유정',
#   '악플',
#   '쓰다',
#   '애',
#   '박사모',
#   '로',
#   '취급',
#   '되다',
#   'ㅋㅋ',
#   '꼰대년넘들',
#   '새해',
#   '부터',
#   '댓글알바',
#   '질',
#   '이고'],
#  ['어제',
#   '보다',
#   '남자',
#   '인',
#   '박보검',
#   '보다',
#   '김유정',
#   '덩',
#   '치가',
#   '더',
#   '크다',
#   '더',
#   '만',
#   '살',
#   '빼다',
#   '같다',
#   '그리고',
#   '웬만하다',
#   '킬힐',
#   '신다',
#   '키',
#   '크다',
#   '않다',
#   '킬힐',
#   '신다',
#   '안다',
#   '저번',
#   '에도',
#   '넘어지다',
#   '뻔하다',
#   '신발',
#   '만',
#   '벗겨지다',
#   '사진',
#   '에서',
#   '보다',
#   '아슬아슬하다'],
#  ['솔직하다', '남자', '보다', '김유정', '제일', '이쁘다'],
#  ['여자',
#   '젤',
#   '이쁘다',
#   '때',
#   '지',
#   '살다',
#   '면',
#   '더',
#   '이쁘다',
#   'ㅎㅎ',
#   '안',
#   '이쁘다',
#   '여자',
#   '애',
#   '나이',
#   '되다',
#   '이쁘다',
#   '좋다',
#   '때',
#   '다'],
#  ['어제', '보다', '김유정', '살', '찌다'],
#  ['성인',
#   '되다',
#   '축하',
#   '병신',
#   '같다',
#   '한국',
#   '나이',
#   '그만',
#   '쓰다',
#   '나',
#   '그저께',
#   '생일',
#   '이다',
#   '바로',
#   '살',
#   '먹음',
#   'ㅠㅠ',
#   '요즘',
#   '시',
#   '험준',
#   '비다',
#   '며칠',
#   '차이',
#   '로',
#   '뒤',
#   '치다',
#   '차다'],
#  ['진지희',
#   '일단',
#   '내려놓다',
#   '김소현',
#   '이랑',
#   '김유정',
#   '이쁘다',
#   '김유정',
#   '분위기',
#   '까지',
#   '있다',
#   '김유정',
#   '제일',
#   '최고',
#   '인',
#   '듯'],
#  ['과즙', '미소'],
#  ['김유정', '몸매', '로', '다', '이기다'],
#  ['정직하다', '김소현', '넘사벽', '김유', '정진', '소희', '아니다'],
#  ['유정', '미모', '실화', '얼마나', '더', '이쁘다', '지리다'],
#  ['세',
#   '명',
#   '다',
#   '케릭',
#   '터',
#   '정말',
#   '틀리다',
#   '너무나',
#   '빛나다',
#   '이쁘다',
#   'ㅠ',
#   '좋다',
#   '작품',
#   '많이',
#   '찍다',
#   '저',
#   '지',
#   '금은',
#   '진지희',
#   '양',
#   '젤',
#   '좋다',
#   '비주',
#   '얼',
#   '젤',
#   '약하다',
#   '차다',
#   '분위기',
#   '있다',
#   '커서',
#   '요',
#   '백',
#   '희다',
#   '돌아오다',
#   '보구',
#   '완전',
#   '반했어',
#   '요',
#   '유정',
#   '양',
#   '이야',
#   '말함입',
#   '아프다',
#   '세분',
#   '중',
#   '현재',
#   '원',
#   '탑',
#   '죠',
#   '연기',
#   '되다',
#   '외모',
#   '되다',
#   '볼',
#   '매다',
#   'ㅎㅎ',
#   '정말',
#   '좋다',
#   '작품',
#   '만',
#   '나',
#   '김혜수',
#   '씨',
#   '처럼',
#   '대체',
#   '불가',
#   '여배우',
#   '로',
#   '성장하다',
#   '진심',
#   '진심',
#   '혜수',
#   '씨',
#   '능가',
#   '소현',
#   '양',
#   '외모',
#   '너무',
#   '청순',
#   '이쁘다',
#   '이쁘다',
#   '연',
#   '기도',
#   '살짝',
#   '부족하다',
#   '외모',
#   '넘다',
#   '이쁘다',
#   'ㅎㅎ',
#   '평생',
#   '안다',
#   '야하다',
#   '숙제',
#   '배우',
#   '넘다',
#   '이쁘다',
#   '축복',
#   '지다',
#   '카리스마',
#   '본인',
#   '무기',
#   '꼭',
#   '만들다'],
#  ['술', '한잔', '같다', '이해도', '되다'],
#  ['김유정', '가슴', '존나', '크다'],
#  ['김유정', '진지희', '사랑'],
#  ['진지희', '진짜', '분위기', '있다', '청순하다'],
#  ['그래도',
#   '아직',
#   '다',
#   '들다',
#   '애기',
#   '같다',
#   '대다',
#   '중후',
#   '반',
#   '넘어가다',
#   '역할',
#   '무리',
#   '임',
#   '당분간',
#   '어리다',
#   '대학생',
#   '역할',
#   '까지만',
#   '가능하다'],
#  ['몇', '년안', '김소현', '한국', '최고', '원', '탑', '미녀', '배우', '되다', '장담'],
#  ['친일파', '면', '어떻다', '나다', '왠지', '친일', '파이다', '헤헷'],
#  ['한반도',
#   '역사상',
#   '최고',
#   '지도자',
#   '박정희',
#   '대통령',
#   '이고',
#   '이건',
#   '전세계',
#   '인정',
#   '사실',
#   '임그',
#   '뒤',
#   '전두환',
#   '이라고',
#   '해도',
#   '되다',
#   '걸',
#   '자꾸',
#   '부정',
#   '하고',
#   '왜곡',
#   '하고',
#   '사실',
#   '다르다',
#   '거짓',
#   '정보',
#   '제공',
#   '언론',
#   '계',
#   '문화',
#   '계',
#   '예술',
#   '계',
#   '진짜',
#   '문제',
#   '많다'],
#  ['절', '라', '디', '언', '생떼', '쓰다', '영화'],
#  ['친일파',
#   '조',
#   '상이',
#   '업적',
#   '별',
#   '얘기',
#   '없이',
#   '지나가다',
#   '같다',
#   '옹호',
#   '하',
#   '듯',
#   '침묵',
#   '비슷하다',
#   '기사',
#   '읽다',
#   '기억'],
#  ['좌빨', '영화', '전라디언', '영화'],
#  ['정치', '선동', '영화', '전라디언', '영화', '전라디언', '반', '대표', '누르다', '욤'],
#  ['영화',
#   '그냥',
#   '허구',
#   '적',
#   '인거',
#   '임',
#   '너무',
#   '사실',
#   '달리',
#   '왜곡',
#   '하고',
#   '과장',
#   '돼다',
#   '김대중',
#   '을',
#   '미화',
#   '그냥',
#   '웃음',
#   '만',
#   '나오다',
#   '노무현',
#   '더불다',
#   '일',
#   '자다',
#   '대통령',
#   '아니다',
#   '전두환',
#   '역대',
#   '대통령',
#   '중',
#   '가장',
#   '일',
#   '자다',
#   '분',
#   '중',
#   '분',
#   '임원',
#   '탑',
#   '박정희',
#   '인',
#   '건',
#   '전세계',
#   '인정',
#   '것',
#   '이고',
#   '이렇다',
#   '영화',
#   '만들다',
#   '젊다',
#   '세대',
#   '한테',
#   '못',
#   '되다',
#   '역사관',
#   '심다',
#   '안되다',
#   '젊다',
#   '세대',
#   '을',
#   '너무',
#   '선동'],
#  ['박정희',
#   '대통령',
#   '대한민국',
#   '끼치다',
#   '업적',
#   '만배',
#   '더',
#   '많다',
#   '왜',
#   '박정희',
#   '대통령',
#   '기념',
#   '사업',
#   '회',
#   '못',
#   '방해'],
#  ['작품', '성은', '좋다', '영화', '자체', '따분하다', '졸림'],
#  ['박근혜', '정권', '서슬', '퍼렇다', '개도', '웃', '을', '일이', '다', '년대', '사시', '분', '인가'],
#  ['우리', '또', '만나다', 'ㅋㅋㅋㅋㅋㅋㅋㅋ', '정', '들것', '네', 'ㅋ'],
#  ...]

# %%
from gensim.models import Word2Vec

model = Word2Vec(sentences = tokenized_data, size = 100, window = 5, 
                 min_count = 5, workers = 4, sg = 1)

# %%
print(model.wv.most_similar("배우", topn = 5))
print(model.wv.most_similar("소녀시대", topn = 5))
print(model.wv.most_similar("대한민국", topn = 5))
print(model.wv.most_similar("김유정", topn = 5))
# Out:
# [('연기자', 0.8405822515487671), ('여배우', 0.7437516450881958), ('조연', 0.722025990486145), ('다작', 0.7164419889450073), ('주연', 0.7147039175033569)]
# [('소시', 0.8357353210449219), ('포미닛', 0.8037329912185669), ('애프터스쿨', 0.8019363284111023), ('카라', 0.7952439188957214), ('원걸', 0.7767716646194458)]
# [('우리나라', 0.7869008183479309), ('이나라', 0.761174201965332), ('헬조선', 0.7139056921005249), ('전세계', 0.6928060054779053), ('은나라', 0.6830878257751465)]
# [('김소현', 0.8455526232719421), ('김새론', 0.8036403059959412), ('진지희', 0.7982784509658813), ('남주혁', 0.7837553024291992), ('송재림', 0.777401864528656)]
